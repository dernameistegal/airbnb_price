# %% [markdown]
# <a href="https://colab.research.google.com/github/dernameistegal/airbnb_price/blob/main/Model_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Simple tutorial on exploratory model building on a subset of the Airbnb dataset.
#
# In this introductory notebook, we will take a closer look at the Airbnb data. This is by no means a "perfect" analysis, but serves only as an introduction to how one might approach a problem such as the one at hand. So the analyses performed are only meant as a kind of inspiration for your own models.
#
# The variable selection is arbitrary and not every potentially valuable variable is used. We will for instance only use some of the structural variables and the images, but no text data.
#
# In this simple tutorial you will learn:
#
# * How to read in and read out the images for modeling.
# * How to deal with missing data
#     * Simple imputation transformations to fill in missing values, such as using the median
# * How to preprocess structural variables
# * Creating base models for the structural variables for data exploration.
#     * Simple linear regression
#     * Decision Tree Regression
#     * Random Forest Regression
# * How to create a Multi Layer Perceptron (MLP).
#     * How to use sklearn and tensorflow.keras
# * How to build a basic Convolutional Neural Network (CNN).
# * Predicting the RMSE using your CNN architecture.
# * How to build a CNN with multiple inputs and mixed data.
#
#
# The goal of your analyses is to build a model that predicts Airbnb rental prices fairly accurately while providing good interpretability.

# %% [markdown]
# ## Index
# #### 1. Load the data and scrape the images
#
# #### 2. Data Exploration
#
# #### 3. Model building using only the structural variables
#
# #### 4. Model building using the images

# %% [markdown]
# # 1. Load the data

# %%
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import requests
from io import BytesIO
import matplotlib.image as mpimg
from tqdm import tqdm

import seaborn as sns

# %% [markdown]
# I chose only to use the first 1000 observations of the available data to have a faster computation time.
# In this tutorial we will not use the 4 datasets loaded below but will solely focus on the listings.csv.gz file.

# %%
listings = pd.read_csv("listings.csv")[0:500]
reviews = pd.read_csv("reviews.csv")[0:500]
reviews_meta = pd.read_csv("reviews.csv.gz")[0:500]
calendar = pd.read_csv("calendar.csv.gz")[0:500]

# %% [markdown]
# Load the main data file

# %%
train_df = pd.read_csv("listings.csv.gz")[0:1000]

# %%
# drop all rows where no pictures are available
train_df = train_df.dropna(subset=["picture_url", "host_picture_url"])
train_df = train_df.reset_index(drop=True)

# %% [markdown]
# Unfortunately, the variable we are interested in, the price, is given in a string format in the form of  "10.00$".
#
# For easier computation we transform these strings into floats

# %%
# transform price
train_df["price"] = (
    train_df["price"].str.replace("$", "").str.replace(",", "").astype(float)
)

# %% [markdown]
# Additionaly let's compute the log price, as predicting the log price gives us some advantages we will see later in the notebook

# %%
train_df["log_price"] = np.log(train_df["price"])

# %% [markdown]
# As you can see below, we have an enormous amount of available data (75 columns + additional files). However, some of these variables contain essentially the same or extremely correlated information. For example, I would guess that the sentiment of a written review is highly correlated with the given *star* rating.

# %%
train_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'log_price'],
#       dtype='object')

# %% [markdown]
# Let's have a quick look at the data. We have 75 columns with a lot of variables that probably do not bare any explanation in them at all.

# %%
train_df.head()
# Out:
#       id                         listing_url  ...  reviews_per_month log_price
# 0  15883  https://www.airbnb.com/rooms/15883  ...               0.29  4.787492
# 1  38768  https://www.airbnb.com/rooms/38768  ...               2.92  4.110874
# 2  40625  https://www.airbnb.com/rooms/40625  ...               1.85  4.875197
# 3  51287  https://www.airbnb.com/rooms/51287  ...               2.78  4.077537
# 4  70637  https://www.airbnb.com/rooms/70637  ...               0.95  3.912023
#
# [5 rows x 75 columns]

# %% [markdown]
# ### "Scrape" the images
#
# First, we try to scrape the available images:
#
# This loop, as terrible as it is written, loops through the given flat-picture and host-picture URL's and appends the scraped pictures to two lists. We resize the images to a size of 224 by 224 pixels and normalize them by dividing through 255 (the maximum pixel value). All images that cannot be scraped or are not with rgb are dropped from the dataframe. This is obviously optional and can be handled differently by your approach.
#
# The used picture size of 224x224 is also done randomly. Have in mind, however, that larger pixel values (while maybe giving you better prediction results) will give you longer computation times. However, using e.g. 8x8 images as is sometimes done with the MNIST data sets will give you unrecognizable flat images.
#
# Depending on your number of observations this can take a while. Therefore it is sensible for you (if you haven't already) to start your analysis by scrapping all images and (obviously) saving them.

# %%
pictures_flat = []
pictures_host = []
for i in tqdm(range(len(train_df))):

    # retrieve image from url
    
    response_flat = requests.get(train_df["picture_url"][i])
    response_host = requests.get(train_df["host_picture_url"][i])

    # resize images so they all have the same size
    img_flat = Image.open(BytesIO(response_flat.content)).resize([64, 64])
    img_host = Image.open(BytesIO(response_host.content)).resize([64, 64])

    # normalize (divide by maximum pixel value (255))
    img_flat = np.array(img_flat) / 255.0
    img_host = np.array(img_host) / 255.0
    
    try:
        # check shape for nn input
        if img_flat.shape != (64, 64, 3):
            img_flat = img_flat[:, :, 0:3]
            
        if img_host.shape != (64, 64, 3):
            img_host = img_host[:, :, 0:3]
         
        # append the images to the created empty lists
        pictures_flat.append(img_flat)
        pictures_host.append(img_host)
            
    except IndexError:
        train_df = train_df.drop([i])
# Out:
# 100%|██████████| 999/999 [06:28<00:00,  2.57it/s]

# %%
train_df["pic_host"] = pictures_host
train_df["pic_flat"] = pictures_flat

# %%
train_images_flat = np.asarray(pictures_flat)
train_images_host = np.asarray(pictures_host)

# %%
#@title
np.median(train_df["price"])
# Out:
# 66.0

# %% [markdown]
# # 2. Data Exploration
#
# First we take a closer look at the price distribution of the given data.
# We can clearly see that we have a wide range of prices and very few observations at the very top of the price range.
# The average airbnb apartment is rented for \$101.5 per night. The median lies at 72.

# %%
sns.set(rc={"figure.figsize": (15, 5)})
fig = plt.figure()
sns.histplot(data=train_df, x="price", bins=50)
plt.axvline(train_df["price"].mean(), c="red", ls="-", lw=3, label="Mean Price")
plt.axvline(train_df["price"].median(), c="blue", ls="-", lw=3, label="Median Price")
plt.title("Distribution of Airbnb Prices", fontsize=20, fontweight="bold")
plt.legend()
plt.show()

# %% [markdown]
# Sometimes it might be advisable to take a closer look at the log-distribution of the prices, which, often depending on the chosen sample size, looks pretty much like a normal distribution.

# %%
sns.set(rc={"figure.figsize": (15, 5)})
fig = plt.figure()
sns.histplot(data=train_df, x="log_price", bins=50)
plt.axvline(train_df["log_price"].mean(), c="red", ls="-", lw=3, label="Mean Log Price")
plt.axvline(
    train_df["log_price"].median(),
    c="blue",
    ls="-",
    lw=3,
    label="Median Log Price",
)
plt.title("Distribution of Airbnb Log Prices", fontsize=20, fontweight="bold")
plt.legend()
plt.show()

# %% [markdown]
# Additionaly we take a closer look at some of the variables which are chosen at random, although I do expect that the chosen 3 variables, namely the room type, whether the host is a so-called "superhost" and the number of people the apartment accomodates has a significant impact on the rental price. However, this is by no means validated and thus you should not be too strongly influenced by my choice.

# %%
feature_variables = [
    "room_type",
    "host_is_superhost",
    "accommodates",
]

# for each of the above listed feature variables
# show a boxplot and distribution plot against the log price
for variable in feature_variables:
    fig, ax = plt.subplots(1, 2)
    sns.boxplot(data=train_df, x=variable, y="log_price", ax=ax[0])
    sns.histplot(train_df, x="log_price", hue=variable, kde=True, ax=ax[1])
    plt.suptitle(variable, fontsize=20, fontweight="bold")
    fig.show()

# %% [markdown]
# Now, we take a look at the host images and the flat images. Therefore we write a simple function that plots the stored images and labels them with the given apartment rental price.

# %%
def plot_images_and_prices(
    df, desired_price=None, num_images=5, random_state=202, pics="pic_host"
):
    """plots images and respective prices

    Args:
        df (pd.DataFrame): DataFrame eveyrthing is stored in. Prices and images as arrays
        desired_price (float, optional): If you want to only view images with a specified rental price. Defaults to None.
        num_images (int, optional): Number of images to be plotted. Defaults to 5.
        random_state (int, optional): . Defaults to 101.
        pics (str, optional): column Name in df where images are stored. Defaults to "pic_host".
    """

    num_images = num_images

    # set the rample state for the sampling for reproducibility
    random_state = random_state

    # only select entries with given price when specified
    if desired_price != None:
        random_sample = (
            df[df["price"] == desired_price]
            .sample(num_images, random_state=random_state)
            .reset_index(drop=True)
        )
    else:
        random_sample = df.sample(num_images, random_state=random_state)

    for i in range(num_images):

        price = random_sample.iloc[i]["price"]
        plt.subplot(1, num_images, i + 1)

        title = price
        plt.title(title)

        # turn off gridlines
        plt.axis("off")

        plt.imshow(random_sample.iloc[i][pics])
    plt.show()
    plt.close()

# %%
# plot the hosts
plot_images_and_prices(train_df)

# %%
# plot the flats
plot_images_and_prices(train_df, pics="pic_flat")

# %% [markdown]
# # 3. Model building

# %% [markdown]
# To create a model, simpler models are first examined. This can be used, for example, to select the appropriate variables, since simple models often offer good interpretability.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
import matplotlib.patches as mpatches
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPRegressor

from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

from sklearn.impute import SimpleImputer

from math import e

# %% [markdown]
# First, we select only a few of the variables for easier computation. An adewuate variable selection will be of crucial importance for your model, however, for this simple introduction I just picked what I thought might be reasonable. Additionaly, I chose variables that might be correlated with one another as bedrooms and beds, but did not adjust for that in my modeling as you might see later.
#
# We choose the log-price as Y, as we will start with a simple linear regression where the normality assumption is crucial.
#
# As the chosen feature variables we selected:
#
# * "host_is_superhost"
# * "latitude"
# * "longitude"
# * "room_type"
# * "accommodates"
# * "bedrooms"
# * "number_of_reviews"
# * "review_scores_value"
#
#
# Most of these are self explanatory, but you can look up their exact meaning at: https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=982310896

# %%
Y = train_df["log_price"]

train_df = train_df[
    [
        "host_is_superhost",
        "latitude",
        "longitude",
        "room_type",
        "accommodates",
        "bedrooms",
        "minimum_nights",
        "number_of_reviews",
        "review_scores_value",
        "host_identity_verified",
    ]
]

# %% [markdown]
# There are several ways to deal with missing data. The obvious one is to simply drop all rows where you encounter any missing (or unreasonable, e.g. 10 billion beds) values. Sometimes this might even be advisable. However, I chose to use a fairly straight forward method by simply replacing the missing values with the respective median values of the features. I chose the median, as the mean of e.g. number of bedrooms is not really meaningful, with e.g. 1.19.
#
# Additionally we dummy decode the column "room_type", hus creating additional columns.

# %%
train_df.isna().sum()
# Out:
# host_is_superhost          0
# latitude                   0
# longitude                  0
# room_type                  0
# accommodates               0
# bedrooms                  95
# minimum_nights             0
# number_of_reviews          0
# review_scores_value       86
# host_identity_verified     0
# dtype: int64

# %%
imputer = SimpleImputer(strategy="median")


imputer = imputer.fit(
    train_df[
        [
            "accommodates",
            "bedrooms",
            "number_of_reviews",
            "review_scores_value",
            "minimum_nights",
        ]
    ]
)

train_df[
    [
        "accommodates",
        "bedrooms",
        "number_of_reviews",
        "review_scores_value",
        "minimum_nights",
    ]
] = imputer.transform(
    train_df[
        [
            "accommodates",
            "bedrooms",
            "number_of_reviews",
            "review_scores_value",
            "minimum_nights",
        ]
    ]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
rooms = pd.get_dummies(train_df["room_type"], prefix="room")
train_df = train_df.drop("room_type", axis=1)
train_df["host_is_superhost"] = train_df["host_is_superhost"].map(dict(t=1, f=0))
train_df["host_identity_verified"] = train_df["host_identity_verified"].map(
    dict(t=1, f=0)
)
train_df = pd.concat([train_df, rooms], axis=1)
train_df
# Out:
#      host_is_superhost  latitude  ...  room_Private room  room_Shared room
# 0                    0  48.24262  ...                  0                 0
# 1                    1  48.21924  ...                  0                 0
# 2                    1  48.18434  ...                  0                 0
# 3                    1  48.21778  ...                  0                 0
# 4                    1  48.21760  ...                  1                 0
# ..                 ...       ...  ...                ...               ...
# 994                  1  48.17406  ...                  0                 0
# 995                  0  48.22429  ...                  1                 0
# 996                  0  48.20087  ...                  0                 0
# 997                  0  48.17834  ...                  0                 0
# 998                  0  48.21670  ...                  0                 0
#
# [999 rows x 13 columns]

# %% [markdown]
# For a visual interpretation of our following model results we define a simple plotting function that plots the actual prices vs our predicted prices

# %%
# let's see what our predictions look like vs the actual
def ActualvPredictionsGraph(test_y, pred_y, title, prob=False):
    if max(test_y) >= max(pred_y):
        my_range = int(max(test_y))
    else:
        my_range = int(max(pred_y))
    plt.figure(figsize=(12, 3))
    plt.scatter(range(len(test_y)), test_y, color="blue")
    plt.scatter(range(len(pred_y)), pred_y, color="red")
    plt.xlabel("Index ")
    plt.ylabel("Log_price")
    plt.title(title, fontdict={"fontsize": 15})
    plt.legend(
        handles=[
            mpatches.Patch(color="red", label="prediction"),
            mpatches.Patch(color="blue", label="actual"),
        ]
    )
    plt.show()

    if prob:
        # plot actual v predicted in histogram form
        plt.figure(figsize=(12, 4))
        sns.histplot(predict_test, color="r", alpha=0.3, stat="probability", kde=True)
        sns.histplot(test_y, color="b", alpha=0.3, stat="probability", kde=True)
        plt.legend(labels=["prediction", "actual"])
        plt.title("Actual v Predict Distribution" + str(title))
        plt.show()

# %% [markdown]
# Before we start modelling, we need to agree on an evaluation method. Obviously for a simple linear regression we could use the R^2, adjusted R2 or AIC metric, but as later we are introducing neural networks I want to use a simple and straight forward method of evluating the model predictions. For that purpose we will use the Root Mean Square Error (RMSE) metric.
#
# \begin{equation}
# RMSE = \sqrt {\sum_{i=1}^{n} \frac{\hat{y_i} - y_i}{n}},
# \end{equation}
#
# where $\hat{y}$ is the predicted price. Be aware that the imported function is only the Mean Squared Error (MSE) which is why we take the squareroot by using **0.5
#
#
# For that purpose we will split our data set into a training data set and a testing data set.

# %%
train_x, test_x, train_y, test_y = train_test_split(
    train_df, Y, test_size=0.25, random_state=0
)

# %% [markdown]
# First, lets try a "stupid model" that only predicts the mean of the training data, in our case the mean log price of the training data.

# %%
def stupid_model_prediction(y_train, y_test):
    a = np.empty(len(test_y))
    a.fill(np.mean(train_y))
    return a


pred_y = stupid_model_prediction(train_y, test_y)

# %%
print("RMSE on test data: ", mean_squared_error(test_y, pred_y) ** (0.5))
# Out:
# RMSE on test data:  0.5395519960454388

# %%
ActualvPredictionsGraph(test_y, pred_y, "Actual v. Mean")

# %% [markdown]
# ## Linear Regression Model
#
# You should all be familiar with the simple linear regression model.
# \begin{equation}
# \mathbf{Y} = \mathbf{X}\mathbf{\beta} + \mathbf{\epsilon}
# \end{equation}
# However, you might not have fitted a regression using python.
#
# To use a linear regression in python is similarly easy as it is using it in R. Unfortunately, sklearn does not offer a summary as nice as the R-version does. If you are interested in a similar regression output you could use e.g. statsmodels or create the output yourself by e.g. using sklearns metrics as the introduced MSE.

# %%
model_LR = LinearRegression()

# fit the model with the training data
model_LR.fit(train_x, train_y)

predict_train = model_LR.predict(train_x)
predict_test = model_LR.predict(test_x)
# Root Mean Squared Error on train and test date

print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.48457965938058567
# RMSE on test data:  0.4697912699502244

# %%
# plot it
ActualvPredictionsGraph(test_y, predict_test, "Actual v. Predicted LM", prob=True)

# %% [markdown]
# Decision trees are algorithms that can be used in both, regression and classification. They are basically using a set of binary rules and are thus very easy to interpret. A decision tree, just as a real tree has subsequently branches, nodes and leaves.
#
# A tree could e.g. look something like this:
#
# <img src="Screen-Shot-2019-05-17-at-00.09.26.png">
#
# For more information on decision trees see e.g. https://gdcoder.com/decision-tree-regressor-explained-in-depth/ (where this graphic is taken from)

# %%
tree_reg = DecisionTreeRegressor(max_depth=3, min_samples_split=10)

# train the model
tree_reg.fit(train_x, train_y)

# predict the response for the test data
predict_train = tree_reg.predict(train_x)
predict_test = tree_reg.predict(test_x)

# Root Mean Squared Error on train and test date
print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.4699871562103687
# RMSE on test data:  0.4882896883721667

# %%
ActualvPredictionsGraph(test_y, predict_test, "Actual v. Predicted DT", prob=True)

# %%
# visualize the decision tree
fig = plt.figure(figsize=(15, 5))
plot = tree.plot_tree(
    tree_reg, feature_names=train_x.columns.values.tolist(), filled=True
)

# %% [markdown]
# The overall performance of the decision trees is fairly similar to the performance of a simple linear regression. However, wee see an accumulation of predictions around certain prices due to the inherent model structure of binary decisions.
#
# A similar and very common approach is a random forest regression:

# %%
model_RFR = RandomForestRegressor(max_depth=10)

# fit the model with the training data
model_RFR.fit(train_x, train_y)

# predict the target on train and test data
predict_train = model_RFR.predict(train_x)
predict_test = model_RFR.predict(test_x)

# Root Mean Squared Error on train and test date
print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.22172390138400191
# RMSE on test data:  0.46598052172149124

# %%
ActualvPredictionsGraph(test_y, predict_test, "Actual v. Predicted RF", prob=True)

# %%
plt.figure(figsize=(10, 7))
feat_importances = pd.Series(model_RFR.feature_importances_, index=train_x.columns)
feat_importances.nlargest(train_df.shape[1]).plot(kind="barh")

# %% [markdown]
# This plot gives the "importance" of our input variables/features in the model. This could e.g. give us a reason to drop some of our used variables.

# %% [markdown]
# Now we want to build our first Multi Layer Perceptron. In this Notebook I will be using firstly the very inflexible MLPRegressor from scikit-learn and secondly a simple Tensorflow-Keras Implementation. You are, however, by no means in any way restricted and can use e.g. Tensorflow, Pytorch, Caffe or any other library you find suitable or implement everything on your own.
#
# Commonly the weights in neural networks are initialized to random small numbers (most often with a random draw from a truncated normal distribution with mean=0 and variance=1) and updated with a given (and often cahnging/flexible) small learning rate.
# Given this use of small weights the scale of inputs (and outputs) is an important factor. Unscaled input variables can result in a slow or unstable learning process which in turn can lead to a bad performance. Unscaled output variables (in our case the price) can lead to exploding gradients.
#
# As we have already scaled our prices with a log-transformation we will apply a MinMax Scaling approach to our input variables.
#
#
#
# \begin{equation}
# x_{scaled} = \frac{x - min(x)}{max(x) - min(x)}
# \end{equation}
#
#
# ###### As you can see in the formula this has no effect on the dummy variables. However, our implementation has an effect on the "categorical" variables as e.g. "accommodates" or "beds". It might therefore maybe be more approriate to use e.g. One-Hot-Encoding for the categorical variables. I have not implemented this in the present notebook as this is purely introductory, so you should definetly have in mind that the variables selection, feature extraction and preprocessing is a very important part of your model building and should not simply be copied from this notebook

# %%
# try with minmax scaled data -> also usefull for MLP
mn = MinMaxScaler()
x_train_scaled = pd.DataFrame(mn.fit_transform(train_x), columns=train_x.columns)
x_test_scaled = pd.DataFrame(mn.fit_transform(test_x), columns=test_x.columns)

# %%
MLPreg = MLPRegressor(
    hidden_layer_sizes=(1),
    activation="relu",
    random_state=101,
    max_iter=2000,
).fit(x_train_scaled, train_y)

# %%
predict_train = MLPreg.predict(x_train_scaled)
predict_test = MLPreg.predict(x_test_scaled)
# Root Mean Squared Error on train and test date
print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.5051021763573206
# RMSE on test data:  0.7239624207002432

# %%
ActualvPredictionsGraph(test_y, predict_test, "Actual v. Predicted MLP", prob=True)

# %% [markdown]
# Now let's implement a simple MLP with tensorflow Keras:

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from keras.layers import (
    Dense,
    Conv2D,
    Flatten,
    Dropout,
    MaxPool2D,
    AveragePooling2D,
    Input,
    Activation,
    BatchNormalization,
    MaxPooling2D,
    concatenate,
)
from tensorflow.keras.callbacks import EarlyStopping

# %%
# first define the validation split, number of epochs and the batch size

split = 0.2
epochs = 200
batch_size = 64

# %%
# lets create a susper simple model with just 1 layer

model = Sequential()
model.add(Dense(1, activation="linear", input_shape=(x_train_scaled.shape[1],)))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 14
#
# =================================================================
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mse", metrics="mae")

history = model.fit(
    x_train_scaled,
    train_y,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 18ms/step - loss: 14.8060 - mae: 3.7975 - val_loss: 14.3701 - val_mae: 3.7574
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 14.4099 - mae: 3.7452 - val_loss: 13.9710 - val_mae: 3.7042
# Epoch 3/200
# 10/10 [==============================] - 0s 5ms/step - loss: 14.0163 - mae: 3.6927 - val_loss: 13.5808 - val_mae: 3.6515
# Epoch 4/200
# 10/10 [==============================] - 0s 4ms/step - loss: 13.6355 - mae: 3.6411 - val_loss: 13.1968 - val_mae: 3.5988
# Epoch 5/200
# 10/10 [==============================] - 0s 4ms/step - loss: 13.2591 - mae: 3.5892 - val_loss: 12.8220 - val_mae: 3.5466
# Epoch 6/200
# 10/10 [==============================] - 0s 6ms/step - loss: 12.8895 - mae: 3.5379 - val_loss: 12.4543 - val_mae: 3.4946
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 12.5306 - mae: 3.4869 - val_loss: 12.0951 - val_mae: 3.4430
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 12.1793 - mae: 3.4364 - val_loss: 11.7428 - val_mae: 3.3917
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 11.8338 - mae: 3.3862 - val_loss: 11.4003 - val_mae: 3.3410
# Epoch 10/200
# 10/10 [==============================] - 0s 6ms/step - loss: 11.4974 - mae: 3.3363 - val_loss: 11.0663 - val_mae: 3.2908
# Epoch 11/200
# 10/10 [==============================] - 0s 4ms/step - loss: 11.1693 - mae: 3.2870 - val_loss: 10.7381 - val_mae: 3.2407
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 10.8471 - mae: 3.2379 - val_loss: 10.4176 - val_mae: 3.1910
# Epoch 13/200
# 10/10 [==============================] - 0s 5ms/step - loss: 10.5325 - mae: 3.1891 - val_loss: 10.1051 - val_mae: 3.1418
# Epoch 14/200
# 10/10 [==============================] - 0s 4ms/step - loss: 10.2257 - mae: 3.1409 - val_loss: 9.7992 - val_mae: 3.0929
# Epoch 15/200
# 10/10 [==============================] - 0s 5ms/step - loss: 9.9259 - mae: 3.0927 - val_loss: 9.4998 - val_mae: 3.0442
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 9.6326 - mae: 3.0453 - val_loss: 9.2101 - val_mae: 2.9963
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 9.3481 - mae: 2.9982 - val_loss: 8.9272 - val_mae: 2.9487
# Epoch 18/200
# 10/10 [==============================] - 0s 5ms/step - loss: 9.0698 - mae: 2.9517 - val_loss: 8.6512 - val_mae: 2.9016
# Epoch 19/200
# 10/10 [==============================] - 0s 8ms/step - loss: 8.7977 - mae: 2.9054 - val_loss: 8.3827 - val_mae: 2.8549
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 8.5331 - mae: 2.8595 - val_loss: 8.1206 - val_mae: 2.8086
# Epoch 21/200
# 10/10 [==============================] - 0s 4ms/step - loss: 8.2753 - mae: 2.8141 - val_loss: 7.8629 - val_mae: 2.7624
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 8.0219 - mae: 2.7687 - val_loss: 7.6135 - val_mae: 2.7168
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 7.7771 - mae: 2.7240 - val_loss: 7.3692 - val_mae: 2.6714
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 7.5352 - mae: 2.6797 - val_loss: 7.1337 - val_mae: 2.6269
# Epoch 25/200
# 10/10 [==============================] - 0s 6ms/step - loss: 7.3032 - mae: 2.6358 - val_loss: 6.9021 - val_mae: 2.5823
# Epoch 26/200
# 10/10 [==============================] - 0s 5ms/step - loss: 7.0753 - mae: 2.5922 - val_loss: 6.6771 - val_mae: 2.5382
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 6.8540 - mae: 2.5490 - val_loss: 6.4585 - val_mae: 2.4947
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 6.6385 - mae: 2.5063 - val_loss: 6.2458 - val_mae: 2.4515
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4284 - mae: 2.4640 - val_loss: 6.0395 - val_mae: 2.4089
# Epoch 30/200
# 10/10 [==============================] - 0s 6ms/step - loss: 6.2252 - mae: 2.4221 - val_loss: 5.8385 - val_mae: 2.3666
# Epoch 31/200
# 10/10 [==============================] - 0s 4ms/step - loss: 6.0271 - mae: 2.3807 - val_loss: 5.6429 - val_mae: 2.3247
# Epoch 32/200
# 10/10 [==============================] - 0s 5ms/step - loss: 5.8335 - mae: 2.3397 - val_loss: 5.4530 - val_mae: 2.2832
# Epoch 33/200
# 10/10 [==============================] - 0s 6ms/step - loss: 5.6461 - mae: 2.2990 - val_loss: 5.2682 - val_mae: 2.2421
# Epoch 34/200
# 10/10 [==============================] - 0s 7ms/step - loss: 5.4633 - mae: 2.2587 - val_loss: 5.0887 - val_mae: 2.2015
# Epoch 35/200
# 10/10 [==============================] - 0s 6ms/step - loss: 5.2862 - mae: 2.2191 - val_loss: 4.9148 - val_mae: 2.1613
# Epoch 36/200
# 10/10 [==============================] - 0s 6ms/step - loss: 5.1130 - mae: 2.1796 - val_loss: 4.7475 - val_mae: 2.1220
# Epoch 37/200
# 10/10 [==============================] - 0s 6ms/step - loss: 4.9471 - mae: 2.1409 - val_loss: 4.5832 - val_mae: 2.0825
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 4.7847 - mae: 2.1024 - val_loss: 4.4236 - val_mae: 2.0435
# Epoch 39/200
# 10/10 [==============================] - 0s 5ms/step - loss: 4.6273 - mae: 2.0641 - val_loss: 4.2687 - val_mae: 2.0049
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 4.4737 - mae: 2.0264 - val_loss: 4.1196 - val_mae: 1.9669
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 4.3261 - mae: 1.9892 - val_loss: 3.9751 - val_mae: 1.9295
# Epoch 42/200
# 10/10 [==============================] - 0s 5ms/step - loss: 4.1816 - mae: 1.9525 - val_loss: 3.8354 - val_mae: 1.8925
# Epoch 43/200
# 10/10 [==============================] - 0s 5ms/step - loss: 4.0423 - mae: 1.9163 - val_loss: 3.7001 - val_mae: 1.8559
# Epoch 44/200
# 10/10 [==============================] - 0s 6ms/step - loss: 3.9079 - mae: 1.8803 - val_loss: 3.5683 - val_mae: 1.8196
# Epoch 45/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7767 - mae: 1.8446 - val_loss: 3.4406 - val_mae: 1.7837
# Epoch 46/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.6499 - mae: 1.8095 - val_loss: 3.3169 - val_mae: 1.7482
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5260 - mae: 1.7748 - val_loss: 3.1980 - val_mae: 1.7133
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4077 - mae: 1.7406 - val_loss: 3.0830 - val_mae: 1.6788
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2925 - mae: 1.7070 - val_loss: 2.9719 - val_mae: 1.6448
# Epoch 50/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1816 - mae: 1.6736 - val_loss: 2.8636 - val_mae: 1.6110
# Epoch 51/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0734 - mae: 1.6404 - val_loss: 2.7595 - val_mae: 1.5778
# Epoch 52/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.9693 - mae: 1.6078 - val_loss: 2.6584 - val_mae: 1.5448
# Epoch 53/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8679 - mae: 1.5756 - val_loss: 2.5611 - val_mae: 1.5123
# Epoch 54/200
# 10/10 [==============================] - 0s 7ms/step - loss: 2.7701 - mae: 1.5438 - val_loss: 2.4671 - val_mae: 1.4802
# Epoch 55/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6759 - mae: 1.5125 - val_loss: 2.3758 - val_mae: 1.4484
# Epoch 56/200
# 10/10 [==============================] - 0s 6ms/step - loss: 2.5848 - mae: 1.4812 - val_loss: 2.2875 - val_mae: 1.4169
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.4961 - mae: 1.4507 - val_loss: 2.2032 - val_mae: 1.3860
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4111 - mae: 1.4207 - val_loss: 2.1221 - val_mae: 1.3557
# Epoch 59/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.3294 - mae: 1.3912 - val_loss: 2.0439 - val_mae: 1.3258
# Epoch 60/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2507 - mae: 1.3622 - val_loss: 1.9687 - val_mae: 1.2964
# Epoch 61/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1748 - mae: 1.3339 - val_loss: 1.8964 - val_mae: 1.2673
# Epoch 62/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1013 - mae: 1.3060 - val_loss: 1.8272 - val_mae: 1.2389
# Epoch 63/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0315 - mae: 1.2789 - val_loss: 1.7596 - val_mae: 1.2105
# Epoch 64/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9630 - mae: 1.2519 - val_loss: 1.6953 - val_mae: 1.1829
# Epoch 65/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8980 - mae: 1.2256 - val_loss: 1.6331 - val_mae: 1.1561
# Epoch 66/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8350 - mae: 1.1998 - val_loss: 1.5736 - val_mae: 1.1300
# Epoch 67/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.7740 - mae: 1.1748 - val_loss: 1.5169 - val_mae: 1.1046
# Epoch 68/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.7161 - mae: 1.1502 - val_loss: 1.4619 - val_mae: 1.0792
# Epoch 69/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6599 - mae: 1.1257 - val_loss: 1.4087 - val_mae: 1.0541
# Epoch 70/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6056 - mae: 1.1016 - val_loss: 1.3579 - val_mae: 1.0294
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5540 - mae: 1.0779 - val_loss: 1.3090 - val_mae: 1.0051
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5037 - mae: 1.0549 - val_loss: 1.2624 - val_mae: 0.9816
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4563 - mae: 1.0324 - val_loss: 1.2174 - val_mae: 0.9586
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4101 - mae: 1.0106 - val_loss: 1.1752 - val_mae: 0.9368
# Epoch 75/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3668 - mae: 0.9894 - val_loss: 1.1344 - val_mae: 0.9151
# Epoch 76/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3245 - mae: 0.9688 - val_loss: 1.0954 - val_mae: 0.8939
# Epoch 77/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2837 - mae: 0.9487 - val_loss: 1.0582 - val_mae: 0.8731
# Epoch 78/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2458 - mae: 0.9290 - val_loss: 1.0220 - val_mae: 0.8523
# Epoch 79/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2082 - mae: 0.9096 - val_loss: 0.9880 - val_mae: 0.8324
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1730 - mae: 0.8915 - val_loss: 0.9558 - val_mae: 0.8132
# Epoch 81/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1391 - mae: 0.8736 - val_loss: 0.9252 - val_mae: 0.7950
# Epoch 82/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1072 - mae: 0.8563 - val_loss: 0.8956 - val_mae: 0.7771
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0759 - mae: 0.8393 - val_loss: 0.8676 - val_mae: 0.7600
# Epoch 84/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0469 - mae: 0.8235 - val_loss: 0.8406 - val_mae: 0.7435
# Epoch 85/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0183 - mae: 0.8084 - val_loss: 0.8150 - val_mae: 0.7278
# Epoch 86/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9914 - mae: 0.7939 - val_loss: 0.7908 - val_mae: 0.7128
# Epoch 87/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9659 - mae: 0.7802 - val_loss: 0.7675 - val_mae: 0.6985
# Epoch 88/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9412 - mae: 0.7668 - val_loss: 0.7460 - val_mae: 0.6856
# Epoch 89/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9185 - mae: 0.7543 - val_loss: 0.7253 - val_mae: 0.6733
# Epoch 90/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8961 - mae: 0.7422 - val_loss: 0.7056 - val_mae: 0.6614
# Epoch 91/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8748 - mae: 0.7302 - val_loss: 0.6867 - val_mae: 0.6499
# Epoch 92/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8542 - mae: 0.7186 - val_loss: 0.6691 - val_mae: 0.6393
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8353 - mae: 0.7080 - val_loss: 0.6520 - val_mae: 0.6291
# Epoch 94/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8166 - mae: 0.6978 - val_loss: 0.6358 - val_mae: 0.6194
# Epoch 95/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7991 - mae: 0.6879 - val_loss: 0.6203 - val_mae: 0.6103
# Epoch 96/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7821 - mae: 0.6788 - val_loss: 0.6055 - val_mae: 0.6018
# Epoch 97/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7660 - mae: 0.6700 - val_loss: 0.5916 - val_mae: 0.5937
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7508 - mae: 0.6616 - val_loss: 0.5786 - val_mae: 0.5857
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7365 - mae: 0.6539 - val_loss: 0.5664 - val_mae: 0.5781
# Epoch 100/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7228 - mae: 0.6465 - val_loss: 0.5549 - val_mae: 0.5712
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7101 - mae: 0.6395 - val_loss: 0.5436 - val_mae: 0.5646
# Epoch 102/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6973 - mae: 0.6326 - val_loss: 0.5331 - val_mae: 0.5586
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6855 - mae: 0.6263 - val_loss: 0.5232 - val_mae: 0.5530
# Epoch 104/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6742 - mae: 0.6204 - val_loss: 0.5140 - val_mae: 0.5475
# Epoch 105/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6640 - mae: 0.6149 - val_loss: 0.5050 - val_mae: 0.5420
# Epoch 106/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6537 - mae: 0.6096 - val_loss: 0.4969 - val_mae: 0.5372
# Epoch 107/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6444 - mae: 0.6048 - val_loss: 0.4891 - val_mae: 0.5327
# Epoch 108/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6352 - mae: 0.6001 - val_loss: 0.4821 - val_mae: 0.5285
# Epoch 109/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6271 - mae: 0.5959 - val_loss: 0.4752 - val_mae: 0.5245
# Epoch 110/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6190 - mae: 0.5916 - val_loss: 0.4687 - val_mae: 0.5211
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6112 - mae: 0.5877 - val_loss: 0.4627 - val_mae: 0.5179
# Epoch 112/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6041 - mae: 0.5839 - val_loss: 0.4570 - val_mae: 0.5147
# Epoch 113/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5974 - mae: 0.5804 - val_loss: 0.4514 - val_mae: 0.5116
# Epoch 114/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5907 - mae: 0.5771 - val_loss: 0.4463 - val_mae: 0.5088
# Epoch 115/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5845 - mae: 0.5739 - val_loss: 0.4415 - val_mae: 0.5063
# Epoch 116/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5785 - mae: 0.5708 - val_loss: 0.4371 - val_mae: 0.5042
# Epoch 117/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5731 - mae: 0.5681 - val_loss: 0.4328 - val_mae: 0.5020
# Epoch 118/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5679 - mae: 0.5655 - val_loss: 0.4289 - val_mae: 0.5001
# Epoch 119/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5630 - mae: 0.5630 - val_loss: 0.4254 - val_mae: 0.4984
# Epoch 120/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5585 - mae: 0.5608 - val_loss: 0.4217 - val_mae: 0.4966
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5536 - mae: 0.5587 - val_loss: 0.4184 - val_mae: 0.4950
# Epoch 122/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5497 - mae: 0.5569 - val_loss: 0.4153 - val_mae: 0.4936
# Epoch 123/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5455 - mae: 0.5548 - val_loss: 0.4124 - val_mae: 0.4925
# Epoch 124/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5418 - mae: 0.5532 - val_loss: 0.4096 - val_mae: 0.4914
# Epoch 125/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5382 - mae: 0.5515 - val_loss: 0.4070 - val_mae: 0.4904
# Epoch 126/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5346 - mae: 0.5498 - val_loss: 0.4047 - val_mae: 0.4896
# Epoch 127/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5315 - mae: 0.5483 - val_loss: 0.4025 - val_mae: 0.4889
# Epoch 128/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5285 - mae: 0.5469 - val_loss: 0.4003 - val_mae: 0.4882
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5255 - mae: 0.5454 - val_loss: 0.3983 - val_mae: 0.4877
# Epoch 130/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5229 - mae: 0.5443 - val_loss: 0.3963 - val_mae: 0.4872
# Epoch 131/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5201 - mae: 0.5430 - val_loss: 0.3946 - val_mae: 0.4866
# Epoch 132/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5176 - mae: 0.5418 - val_loss: 0.3929 - val_mae: 0.4862
# Epoch 133/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5154 - mae: 0.5409 - val_loss: 0.3913 - val_mae: 0.4857
# Epoch 134/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5131 - mae: 0.5397 - val_loss: 0.3898 - val_mae: 0.4852
# Epoch 135/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5109 - mae: 0.5387 - val_loss: 0.3884 - val_mae: 0.4847
# Epoch 136/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5088 - mae: 0.5377 - val_loss: 0.3871 - val_mae: 0.4843
# Epoch 137/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5069 - mae: 0.5368 - val_loss: 0.3857 - val_mae: 0.4838
# Epoch 138/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5049 - mae: 0.5358 - val_loss: 0.3845 - val_mae: 0.4834
# Epoch 139/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5031 - mae: 0.5350 - val_loss: 0.3835 - val_mae: 0.4830
# Epoch 140/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5015 - mae: 0.5342 - val_loss: 0.3823 - val_mae: 0.4825
# Epoch 141/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4998 - mae: 0.5333 - val_loss: 0.3812 - val_mae: 0.4821
# Epoch 142/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4981 - mae: 0.5325 - val_loss: 0.3802 - val_mae: 0.4817
# Epoch 143/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4966 - mae: 0.5318 - val_loss: 0.3792 - val_mae: 0.4813
# Epoch 144/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4951 - mae: 0.5309 - val_loss: 0.3783 - val_mae: 0.4810
# Epoch 145/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4938 - mae: 0.5302 - val_loss: 0.3773 - val_mae: 0.4806
# Epoch 146/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4923 - mae: 0.5296 - val_loss: 0.3764 - val_mae: 0.4803
# Epoch 147/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4910 - mae: 0.5290 - val_loss: 0.3755 - val_mae: 0.4800
# Epoch 148/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4898 - mae: 0.5284 - val_loss: 0.3747 - val_mae: 0.4798
# Epoch 149/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4885 - mae: 0.5278 - val_loss: 0.3739 - val_mae: 0.4795
# Epoch 150/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4874 - mae: 0.5273 - val_loss: 0.3731 - val_mae: 0.4793
# Epoch 151/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4862 - mae: 0.5268 - val_loss: 0.3724 - val_mae: 0.4791
# Epoch 152/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4852 - mae: 0.5263 - val_loss: 0.3717 - val_mae: 0.4789
# Epoch 153/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4840 - mae: 0.5257 - val_loss: 0.3709 - val_mae: 0.4787
# Epoch 154/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4830 - mae: 0.5252 - val_loss: 0.3702 - val_mae: 0.4787
# Epoch 155/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4819 - mae: 0.5247 - val_loss: 0.3695 - val_mae: 0.4784
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4809 - mae: 0.5243 - val_loss: 0.3688 - val_mae: 0.4783
# Epoch 157/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4799 - mae: 0.5239 - val_loss: 0.3682 - val_mae: 0.4781
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4790 - mae: 0.5234 - val_loss: 0.3675 - val_mae: 0.4780
# Epoch 159/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4779 - mae: 0.5229 - val_loss: 0.3668 - val_mae: 0.4778
# Epoch 160/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4770 - mae: 0.5225 - val_loss: 0.3661 - val_mae: 0.4775
# Epoch 161/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4761 - mae: 0.5221 - val_loss: 0.3654 - val_mae: 0.4774
# Epoch 162/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4751 - mae: 0.5216 - val_loss: 0.3648 - val_mae: 0.4772
# Epoch 163/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4742 - mae: 0.5212 - val_loss: 0.3641 - val_mae: 0.4770
# Epoch 164/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4734 - mae: 0.5208 - val_loss: 0.3634 - val_mae: 0.4768
# Epoch 165/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4725 - mae: 0.5204 - val_loss: 0.3627 - val_mae: 0.4765
# Epoch 166/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4717 - mae: 0.5200 - val_loss: 0.3621 - val_mae: 0.4763
# Epoch 167/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4708 - mae: 0.5196 - val_loss: 0.3615 - val_mae: 0.4761
# Epoch 168/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4700 - mae: 0.5192 - val_loss: 0.3608 - val_mae: 0.4757
# Epoch 169/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4692 - mae: 0.5187 - val_loss: 0.3601 - val_mae: 0.4754
# Epoch 170/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4684 - mae: 0.5183 - val_loss: 0.3594 - val_mae: 0.4750
# Epoch 171/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4677 - mae: 0.5179 - val_loss: 0.3587 - val_mae: 0.4747
# Epoch 172/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4669 - mae: 0.5174 - val_loss: 0.3580 - val_mae: 0.4742
# Epoch 173/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4661 - mae: 0.5170 - val_loss: 0.3573 - val_mae: 0.4739
# Epoch 174/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4653 - mae: 0.5165 - val_loss: 0.3566 - val_mae: 0.4735
# Epoch 175/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4644 - mae: 0.5161 - val_loss: 0.3559 - val_mae: 0.4733
# Epoch 176/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4636 - mae: 0.5156 - val_loss: 0.3553 - val_mae: 0.4731
# Epoch 177/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4628 - mae: 0.5152 - val_loss: 0.3546 - val_mae: 0.4728
# Epoch 178/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4620 - mae: 0.5148 - val_loss: 0.3539 - val_mae: 0.4724
# Epoch 179/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4612 - mae: 0.5143 - val_loss: 0.3532 - val_mae: 0.4720
# Epoch 180/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4604 - mae: 0.5139 - val_loss: 0.3526 - val_mae: 0.4717
# Epoch 181/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4596 - mae: 0.5135 - val_loss: 0.3519 - val_mae: 0.4713
# Epoch 182/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4589 - mae: 0.5131 - val_loss: 0.3512 - val_mae: 0.4710
# Epoch 183/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4581 - mae: 0.5127 - val_loss: 0.3504 - val_mae: 0.4704
# Epoch 184/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4573 - mae: 0.5122 - val_loss: 0.3496 - val_mae: 0.4699
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4566 - mae: 0.5118 - val_loss: 0.3489 - val_mae: 0.4695
# Epoch 186/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4558 - mae: 0.5113 - val_loss: 0.3481 - val_mae: 0.4689
# Epoch 187/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4551 - mae: 0.5109 - val_loss: 0.3475 - val_mae: 0.4686
# Epoch 188/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4543 - mae: 0.5105 - val_loss: 0.3468 - val_mae: 0.4682
# Epoch 189/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4535 - mae: 0.5101 - val_loss: 0.3462 - val_mae: 0.4679
# Epoch 190/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4528 - mae: 0.5097 - val_loss: 0.3454 - val_mae: 0.4673
# Epoch 191/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4520 - mae: 0.5092 - val_loss: 0.3447 - val_mae: 0.4669
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4513 - mae: 0.5089 - val_loss: 0.3440 - val_mae: 0.4665
# Epoch 193/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4506 - mae: 0.5084 - val_loss: 0.3432 - val_mae: 0.4658
# Epoch 194/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4498 - mae: 0.5079 - val_loss: 0.3425 - val_mae: 0.4653
# Epoch 195/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4491 - mae: 0.5075 - val_loss: 0.3418 - val_mae: 0.4649
# Epoch 196/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4483 - mae: 0.5071 - val_loss: 0.3411 - val_mae: 0.4645
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4476 - mae: 0.5067 - val_loss: 0.3404 - val_mae: 0.4640
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4468 - mae: 0.5062 - val_loss: 0.3396 - val_mae: 0.4634
# Epoch 199/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4461 - mae: 0.5058 - val_loss: 0.3388 - val_mae: 0.4628
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4454 - mae: 0.5053 - val_loss: 0.3381 - val_mae: 0.4623

# %%
loss, mae = model.evaluate(x_test_scaled, test_y)
# Step4.2 Plot the learning curve
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.show()
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4183 - mae: 0.4741

# %%
predict_train = model.predict(x_train_scaled)
predict_test = model.predict(x_test_scaled)
# Root Mean Squared Error on train and test date
print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.6508122678038541
# RMSE on test data:  0.6467531867628261

# %% [markdown]
# # Activation Functions
#
# For this implementation, we will only use two activation functions, namely the Rectified Linear Uni activation function and the linear activation function. However there are obviously multiple other alternatives which could be used.
# The two used activation functions are so-called Ridge functions, as they are multivariate functions acting on a linear combination of the input variables.
#
# ### Rectified Linear Activation Function:
#
# \begin{equation}
# f (x) = \left\{
# \begin{array}{ll}
# x & x > 0 \\
# 0 & \, \textrm{else} \\
# \end{array}
# \right.
# \end{equation}
#
# The ReLU activation function is pretty simple. It is 0, once x is smaller or equal to zero and x, whenever x is bigger than zero. We could write this function in a loop simply as:
# ```
# outputs = []
# for value in inputs:
#     if value > 0:
#         outputs.append(x)
#     elif value <= 0:
#         outputs.append(0)
# ```
#
# However, this can easily be done in one line, by simply taking the maximum between the value itself and 0:
#
# ```
# np.maximum(0, value)
# ```
#
# The derivative of the ReLU function is equally as easy and simply not defined for x = 0:
#
# \begin{equation}
# f (x) = \left\{
# \begin{array}{ll}
# 1 & x > 0 \\
# 0 & x < 0 \\
# \end{array}
# \right.
# \end{equation}
#
# ### Linear
# just returns the input as it is
#
# Let's define these functions and visualize them. Luckily, when using activation functions in our models, they are impemented in basically all available librarys and can simply be used, e.g. with activation="ReLU" in Tensorflow-Keras.

# %%
def ReLU(inputs):
    return np.maximum(0, inputs)

def linear(inputs):
    return inputs

# %%
# Now lets first create some artificial input

x = np.linspace(-10, 10, 500)

# And then plot the two activation functions

plt.plot(x, ReLU(x))
plt.title("Activation Function :ReLu")
plt.show()


plt.plot(x, linear(x))
plt.title("Activation Function :Linear")
plt.show()

# %% [markdown]
# Now we will build a more complex MLP with multiple Layers, but always use the linear activation function

# %%
# let's build a more complex model and increase the number of epochs
epochs = 500

model = Sequential()
model.add(Dense(64, activation="linear", input_shape=(x_train_scaled.shape[1],)))
model.add(Dense(128, activation="linear"))
model.add(Dense(64, activation="linear"))
model.add(Dense(32, activation="linear"))
model.add(Dense(1, activation="linear"))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 64)                896
#
#  dense_3 (Dense)             (None, 128)               8320
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 19,585
# Trainable params: 19,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The number of parameters for a MLP is very simply calculated by calculating the connections between layers + biases in every layer.
#
# \begin{equation}
# n_{params} = (i×h + h×o) + (h+o)
# \end{equation}
#
# where i = input,
# h = hidden layers
# o = output.
#
# For our model, this gives us:
# \begin{equation}
# 12*64 + 64*128 + 128*64 + 64*32 + 32*1 + 64 + 128 + 64 + 32 +1
# = 19521
# \end{equation}

# %%
model.compile(optimizer="adam", loss="mse", metrics="mae")

history = model.fit(
    x_train_scaled,
    train_y,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
)
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 26ms/step - loss: 7.4159 - mae: 2.2796 - val_loss: 1.6646 - val_mae: 1.1230
# Epoch 2/500
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3997 - mae: 0.9778 - val_loss: 0.3659 - val_mae: 0.4681
# Epoch 3/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7138 - mae: 0.6559 - val_loss: 0.3358 - val_mae: 0.4538
# Epoch 4/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4766 - mae: 0.5216 - val_loss: 0.3559 - val_mae: 0.4867
# Epoch 5/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3892 - mae: 0.4569 - val_loss: 0.2565 - val_mae: 0.3969
# Epoch 6/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3563 - mae: 0.4308 - val_loss: 0.2548 - val_mae: 0.4020
# Epoch 7/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3480 - mae: 0.4297 - val_loss: 0.2117 - val_mae: 0.3632
# Epoch 8/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3388 - mae: 0.4166 - val_loss: 0.2083 - val_mae: 0.3633
# Epoch 9/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3235 - mae: 0.4104 - val_loss: 0.2016 - val_mae: 0.3571
# Epoch 10/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3157 - mae: 0.4027 - val_loss: 0.1963 - val_mae: 0.3515
# Epoch 11/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3099 - mae: 0.3981 - val_loss: 0.1940 - val_mae: 0.3482
# Epoch 12/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3054 - mae: 0.3944 - val_loss: 0.1861 - val_mae: 0.3399
# Epoch 13/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3019 - mae: 0.3906 - val_loss: 0.1813 - val_mae: 0.3362
# Epoch 14/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2980 - mae: 0.3866 - val_loss: 0.1800 - val_mae: 0.3309
# Epoch 15/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2925 - mae: 0.3816 - val_loss: 0.1787 - val_mae: 0.3277
# Epoch 16/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2893 - mae: 0.3785 - val_loss: 0.1783 - val_mae: 0.3262
# Epoch 17/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2890 - mae: 0.3834 - val_loss: 0.1705 - val_mae: 0.3252
# Epoch 18/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2857 - mae: 0.3781 - val_loss: 0.1825 - val_mae: 0.3327
# Epoch 19/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2829 - mae: 0.3736 - val_loss: 0.1685 - val_mae: 0.3194
# Epoch 20/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2810 - mae: 0.3717 - val_loss: 0.1672 - val_mae: 0.3149
# Epoch 21/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2834 - mae: 0.3747 - val_loss: 0.1752 - val_mae: 0.3218
# Epoch 22/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2784 - mae: 0.3695 - val_loss: 0.1671 - val_mae: 0.3146
# Epoch 23/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2773 - mae: 0.3700 - val_loss: 0.1637 - val_mae: 0.3149
# Epoch 24/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2754 - mae: 0.3677 - val_loss: 0.1661 - val_mae: 0.3149
# Epoch 25/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2795 - mae: 0.3729 - val_loss: 0.1703 - val_mae: 0.3306
# Epoch 26/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2785 - mae: 0.3732 - val_loss: 0.1687 - val_mae: 0.3154
# Epoch 27/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2707 - mae: 0.3629 - val_loss: 0.1683 - val_mae: 0.3169
# Epoch 28/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2699 - mae: 0.3663 - val_loss: 0.1742 - val_mae: 0.3211
# Epoch 29/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2725 - mae: 0.3659 - val_loss: 0.1714 - val_mae: 0.3197
# Epoch 30/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2693 - mae: 0.3657 - val_loss: 0.1624 - val_mae: 0.3177
# Epoch 31/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2696 - mae: 0.3677 - val_loss: 0.1584 - val_mae: 0.3131
# Epoch 32/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2781 - mae: 0.3745 - val_loss: 0.1691 - val_mae: 0.3299
# Epoch 33/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2856 - mae: 0.3802 - val_loss: 0.1856 - val_mae: 0.3380
# Epoch 34/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2673 - mae: 0.3647 - val_loss: 0.1621 - val_mae: 0.3117
# Epoch 35/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2663 - mae: 0.3648 - val_loss: 0.1572 - val_mae: 0.3108
# Epoch 36/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2770 - mae: 0.3739 - val_loss: 0.1653 - val_mae: 0.3266
# Epoch 37/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2693 - mae: 0.3655 - val_loss: 0.1588 - val_mae: 0.3085
# Epoch 38/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2710 - mae: 0.3646 - val_loss: 0.1919 - val_mae: 0.3415
# Epoch 39/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2681 - mae: 0.3671 - val_loss: 0.1742 - val_mae: 0.3281
# Epoch 40/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2641 - mae: 0.3637 - val_loss: 0.1554 - val_mae: 0.3125
# Epoch 41/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2648 - mae: 0.3612 - val_loss: 0.1598 - val_mae: 0.3095
# Epoch 42/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2614 - mae: 0.3597 - val_loss: 0.1613 - val_mae: 0.3133
# Epoch 43/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2634 - mae: 0.3618 - val_loss: 0.1566 - val_mae: 0.3108
# Epoch 44/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2635 - mae: 0.3605 - val_loss: 0.1697 - val_mae: 0.3180
# Epoch 45/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2614 - mae: 0.3606 - val_loss: 0.1599 - val_mae: 0.3161
# Epoch 46/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2756 - mae: 0.3779 - val_loss: 0.1636 - val_mae: 0.3247
# Epoch 47/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2725 - mae: 0.3720 - val_loss: 0.1698 - val_mae: 0.3308
# Epoch 48/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2809 - mae: 0.3765 - val_loss: 0.1580 - val_mae: 0.3093
# Epoch 49/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2616 - mae: 0.3596 - val_loss: 0.1659 - val_mae: 0.3164
# Epoch 50/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2615 - mae: 0.3618 - val_loss: 0.1528 - val_mae: 0.3091
# Epoch 51/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2597 - mae: 0.3607 - val_loss: 0.1529 - val_mae: 0.3084
# Epoch 52/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2585 - mae: 0.3554 - val_loss: 0.1647 - val_mae: 0.3162
# Epoch 53/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2610 - mae: 0.3597 - val_loss: 0.1618 - val_mae: 0.3157
# Epoch 54/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2694 - mae: 0.3635 - val_loss: 0.1616 - val_mae: 0.3146
# Epoch 55/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2682 - mae: 0.3648 - val_loss: 0.1627 - val_mae: 0.3130
# Epoch 56/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2748 - mae: 0.3705 - val_loss: 0.1539 - val_mae: 0.3153
# Epoch 57/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2745 - mae: 0.3718 - val_loss: 0.1560 - val_mae: 0.3146
# Epoch 58/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2615 - mae: 0.3621 - val_loss: 0.1552 - val_mae: 0.3118
# Epoch 59/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2588 - mae: 0.3595 - val_loss: 0.1720 - val_mae: 0.3246
# Epoch 60/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2647 - mae: 0.3539 - val_loss: 0.2103 - val_mae: 0.3624
# Epoch 61/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2658 - mae: 0.3623 - val_loss: 0.1556 - val_mae: 0.3125
# Epoch 62/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2594 - mae: 0.3601 - val_loss: 0.1916 - val_mae: 0.3449
# Epoch 63/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2659 - mae: 0.3666 - val_loss: 0.1629 - val_mae: 0.3155
# Epoch 64/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2648 - mae: 0.3609 - val_loss: 0.1608 - val_mae: 0.3134
# Epoch 65/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2684 - mae: 0.3681 - val_loss: 0.1579 - val_mae: 0.3143
# Epoch 66/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2631 - mae: 0.3616 - val_loss: 0.1584 - val_mae: 0.3109
# Epoch 67/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2655 - mae: 0.3682 - val_loss: 0.1611 - val_mae: 0.3219
# Epoch 68/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2605 - mae: 0.3610 - val_loss: 0.1549 - val_mae: 0.3160
# Epoch 69/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2830 - mae: 0.3813 - val_loss: 0.1514 - val_mae: 0.3077
# Epoch 70/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2677 - mae: 0.3675 - val_loss: 0.1560 - val_mae: 0.3164
# Epoch 71/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2713 - mae: 0.3656 - val_loss: 0.1615 - val_mae: 0.3140
# Epoch 72/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2683 - mae: 0.3636 - val_loss: 0.1766 - val_mae: 0.3305
# Epoch 73/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2668 - mae: 0.3626 - val_loss: 0.1993 - val_mae: 0.3505
# Epoch 74/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2637 - mae: 0.3631 - val_loss: 0.1534 - val_mae: 0.3109
# Epoch 75/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2605 - mae: 0.3581 - val_loss: 0.1562 - val_mae: 0.3102
# Epoch 76/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2598 - mae: 0.3618 - val_loss: 0.1550 - val_mae: 0.3124
# Epoch 77/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2586 - mae: 0.3586 - val_loss: 0.1533 - val_mae: 0.3093
# Epoch 78/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2666 - mae: 0.3645 - val_loss: 0.1710 - val_mae: 0.3230
# Epoch 79/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2594 - mae: 0.3604 - val_loss: 0.1555 - val_mae: 0.3118
# Epoch 80/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2602 - mae: 0.3597 - val_loss: 0.1582 - val_mae: 0.3117
# Epoch 81/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2631 - mae: 0.3609 - val_loss: 0.1523 - val_mae: 0.3091
# Epoch 82/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2570 - mae: 0.3580 - val_loss: 0.1640 - val_mae: 0.3258
# Epoch 83/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2736 - mae: 0.3693 - val_loss: 0.1536 - val_mae: 0.3148
# Epoch 84/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2596 - mae: 0.3589 - val_loss: 0.1907 - val_mae: 0.3430
# Epoch 85/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2648 - mae: 0.3685 - val_loss: 0.1560 - val_mae: 0.3120
# Epoch 86/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2724 - mae: 0.3746 - val_loss: 0.1556 - val_mae: 0.3163
# Epoch 87/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2609 - mae: 0.3618 - val_loss: 0.1545 - val_mae: 0.3130
# Epoch 88/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2637 - mae: 0.3634 - val_loss: 0.1552 - val_mae: 0.3081
# Epoch 89/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2626 - mae: 0.3619 - val_loss: 0.1551 - val_mae: 0.3105
# Epoch 90/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2590 - mae: 0.3611 - val_loss: 0.1548 - val_mae: 0.3146
# Epoch 91/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2641 - mae: 0.3632 - val_loss: 0.1766 - val_mae: 0.3338
# Epoch 92/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2662 - mae: 0.3652 - val_loss: 0.1512 - val_mae: 0.3070
# Epoch 93/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2703 - mae: 0.3659 - val_loss: 0.1752 - val_mae: 0.3309
# Epoch 94/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2689 - mae: 0.3668 - val_loss: 0.1791 - val_mae: 0.3334
# Epoch 95/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2668 - mae: 0.3611 - val_loss: 0.1921 - val_mae: 0.3449
# Epoch 96/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2614 - mae: 0.3592 - val_loss: 0.1570 - val_mae: 0.3102
# Epoch 97/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2617 - mae: 0.3635 - val_loss: 0.1578 - val_mae: 0.3153
# Epoch 98/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2727 - mae: 0.3768 - val_loss: 0.1758 - val_mae: 0.3311
# Epoch 99/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2612 - mae: 0.3587 - val_loss: 0.1668 - val_mae: 0.3205
# Epoch 100/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2597 - mae: 0.3599 - val_loss: 0.1522 - val_mae: 0.3076
# Epoch 101/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2651 - mae: 0.3630 - val_loss: 0.1581 - val_mae: 0.3166
# Epoch 102/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2581 - mae: 0.3602 - val_loss: 0.1531 - val_mae: 0.3077
# Epoch 103/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2612 - mae: 0.3596 - val_loss: 0.1530 - val_mae: 0.3080
# Epoch 104/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2644 - mae: 0.3610 - val_loss: 0.1530 - val_mae: 0.3108
# Epoch 105/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2598 - mae: 0.3590 - val_loss: 0.1558 - val_mae: 0.3139
# Epoch 106/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2595 - mae: 0.3606 - val_loss: 0.1760 - val_mae: 0.3261
# Epoch 107/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2613 - mae: 0.3588 - val_loss: 0.1540 - val_mae: 0.3100
# Epoch 108/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2620 - mae: 0.3605 - val_loss: 0.1547 - val_mae: 0.3139
# Epoch 109/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2614 - mae: 0.3612 - val_loss: 0.1525 - val_mae: 0.3083
# Epoch 110/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2631 - mae: 0.3622 - val_loss: 0.1585 - val_mae: 0.3147
# Epoch 111/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2659 - mae: 0.3639 - val_loss: 0.1556 - val_mae: 0.3132
# Epoch 112/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2667 - mae: 0.3648 - val_loss: 0.1534 - val_mae: 0.3122
# Epoch 113/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2628 - mae: 0.3629 - val_loss: 0.1556 - val_mae: 0.3138
# Epoch 114/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2665 - mae: 0.3665 - val_loss: 0.1568 - val_mae: 0.3138
# Epoch 115/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2596 - mae: 0.3613 - val_loss: 0.1526 - val_mae: 0.3099
# Epoch 116/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2629 - mae: 0.3619 - val_loss: 0.1528 - val_mae: 0.3100
# Epoch 117/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2603 - mae: 0.3579 - val_loss: 0.1654 - val_mae: 0.3266
# Epoch 118/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2769 - mae: 0.3730 - val_loss: 0.1701 - val_mae: 0.3303
# Epoch 119/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2961 - mae: 0.3957 - val_loss: 0.1828 - val_mae: 0.3426
# Epoch 120/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2861 - mae: 0.3812 - val_loss: 0.1546 - val_mae: 0.3137
# Epoch 121/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2761 - mae: 0.3779 - val_loss: 0.1581 - val_mae: 0.3179
# Epoch 122/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2800 - mae: 0.3724 - val_loss: 0.1619 - val_mae: 0.3194
# Epoch 123/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2613 - mae: 0.3610 - val_loss: 0.1720 - val_mae: 0.3280
# Epoch 124/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2784 - mae: 0.3709 - val_loss: 0.1698 - val_mae: 0.3193
# Epoch 125/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2863 - mae: 0.3906 - val_loss: 0.1835 - val_mae: 0.3390
# Epoch 126/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2627 - mae: 0.3632 - val_loss: 0.1541 - val_mae: 0.3076
# Epoch 127/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2631 - mae: 0.3631 - val_loss: 0.1595 - val_mae: 0.3163
# Epoch 128/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2632 - mae: 0.3624 - val_loss: 0.1678 - val_mae: 0.3207
# Epoch 129/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2581 - mae: 0.3584 - val_loss: 0.1619 - val_mae: 0.3162
# Epoch 130/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2617 - mae: 0.3613 - val_loss: 0.1509 - val_mae: 0.3100
# Epoch 131/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2635 - mae: 0.3608 - val_loss: 0.1544 - val_mae: 0.3137
# Epoch 132/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2572 - mae: 0.3582 - val_loss: 0.1652 - val_mae: 0.3186
# Epoch 133/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2616 - mae: 0.3591 - val_loss: 0.1547 - val_mae: 0.3140
# Epoch 134/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2714 - mae: 0.3725 - val_loss: 0.1883 - val_mae: 0.3402
# Epoch 135/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2707 - mae: 0.3707 - val_loss: 0.1814 - val_mae: 0.3374
# Epoch 136/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2671 - mae: 0.3643 - val_loss: 0.1958 - val_mae: 0.3476
# Epoch 137/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2710 - mae: 0.3731 - val_loss: 0.1667 - val_mae: 0.3217
# Epoch 138/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2627 - mae: 0.3642 - val_loss: 0.1546 - val_mae: 0.3101
# Epoch 139/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2699 - mae: 0.3682 - val_loss: 0.1511 - val_mae: 0.3092
# Epoch 140/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2591 - mae: 0.3597 - val_loss: 0.1659 - val_mae: 0.3182
# Epoch 141/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2610 - mae: 0.3598 - val_loss: 0.1637 - val_mae: 0.3170
# Epoch 142/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2625 - mae: 0.3648 - val_loss: 0.1522 - val_mae: 0.3121
# Epoch 143/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2671 - mae: 0.3662 - val_loss: 0.1541 - val_mae: 0.3126
# Epoch 144/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2613 - mae: 0.3601 - val_loss: 0.1633 - val_mae: 0.3125
# Epoch 145/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2675 - mae: 0.3670 - val_loss: 0.1524 - val_mae: 0.3110
# Epoch 146/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2664 - mae: 0.3673 - val_loss: 0.1553 - val_mae: 0.3164
# Epoch 147/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2614 - mae: 0.3589 - val_loss: 0.1540 - val_mae: 0.3079
# Epoch 148/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2610 - mae: 0.3602 - val_loss: 0.1554 - val_mae: 0.3134
# Epoch 149/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2612 - mae: 0.3632 - val_loss: 0.1523 - val_mae: 0.3103
# Epoch 150/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2650 - mae: 0.3660 - val_loss: 0.1560 - val_mae: 0.3125
# Epoch 151/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2616 - mae: 0.3612 - val_loss: 0.1566 - val_mae: 0.3167
# Epoch 152/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2628 - mae: 0.3647 - val_loss: 0.1531 - val_mae: 0.3118
# Epoch 153/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2612 - mae: 0.3625 - val_loss: 0.1546 - val_mae: 0.3146
# Epoch 154/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2704 - mae: 0.3678 - val_loss: 0.1544 - val_mae: 0.3112
# Epoch 155/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2739 - mae: 0.3726 - val_loss: 0.1548 - val_mae: 0.3142
# Epoch 156/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2700 - mae: 0.3712 - val_loss: 0.1517 - val_mae: 0.3085
# Epoch 157/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2644 - mae: 0.3630 - val_loss: 0.1542 - val_mae: 0.3098
# Epoch 158/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2619 - mae: 0.3616 - val_loss: 0.1544 - val_mae: 0.3125
# Epoch 159/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2590 - mae: 0.3590 - val_loss: 0.1529 - val_mae: 0.3106
# Epoch 160/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2674 - mae: 0.3662 - val_loss: 0.1534 - val_mae: 0.3080
# Epoch 161/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2641 - mae: 0.3624 - val_loss: 0.1580 - val_mae: 0.3142
# Epoch 162/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2641 - mae: 0.3644 - val_loss: 0.1546 - val_mae: 0.3109
# Epoch 163/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2694 - mae: 0.3717 - val_loss: 0.1551 - val_mae: 0.3165
# Epoch 164/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2639 - mae: 0.3620 - val_loss: 0.1535 - val_mae: 0.3096
# Epoch 165/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2589 - mae: 0.3583 - val_loss: 0.1536 - val_mae: 0.3129
# Epoch 166/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2645 - mae: 0.3644 - val_loss: 0.1529 - val_mae: 0.3116
# Epoch 167/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2678 - mae: 0.3658 - val_loss: 0.1573 - val_mae: 0.3126
# Epoch 168/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2609 - mae: 0.3600 - val_loss: 0.1530 - val_mae: 0.3114
# Epoch 169/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2593 - mae: 0.3589 - val_loss: 0.1557 - val_mae: 0.3112
# Epoch 170/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2613 - mae: 0.3591 - val_loss: 0.1682 - val_mae: 0.3211
# Epoch 171/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2771 - mae: 0.3820 - val_loss: 0.1625 - val_mae: 0.3219
# Epoch 172/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2684 - mae: 0.3706 - val_loss: 0.1520 - val_mae: 0.3080
# Epoch 173/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2630 - mae: 0.3619 - val_loss: 0.1536 - val_mae: 0.3103
# Epoch 174/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2650 - mae: 0.3680 - val_loss: 0.1569 - val_mae: 0.3213
# Epoch 175/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2595 - mae: 0.3626 - val_loss: 0.1524 - val_mae: 0.3104
# Epoch 176/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2617 - mae: 0.3626 - val_loss: 0.1561 - val_mae: 0.3164
# Epoch 177/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2751 - mae: 0.3730 - val_loss: 0.1794 - val_mae: 0.3402
# Epoch 178/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2813 - mae: 0.3778 - val_loss: 0.1623 - val_mae: 0.3244
# Epoch 179/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2617 - mae: 0.3634 - val_loss: 0.1523 - val_mae: 0.3101
# Epoch 180/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2625 - mae: 0.3576 - val_loss: 0.1813 - val_mae: 0.3360
# Epoch 181/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2722 - mae: 0.3719 - val_loss: 0.1626 - val_mae: 0.3244
# Epoch 182/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2676 - mae: 0.3681 - val_loss: 0.1615 - val_mae: 0.3131
# Epoch 183/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2598 - mae: 0.3594 - val_loss: 0.1554 - val_mae: 0.3170
# Epoch 184/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2643 - mae: 0.3683 - val_loss: 0.1533 - val_mae: 0.3116
# Epoch 185/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2594 - mae: 0.3586 - val_loss: 0.1618 - val_mae: 0.3221
# Epoch 186/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2800 - mae: 0.3753 - val_loss: 0.1614 - val_mae: 0.3221
# Epoch 187/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2691 - mae: 0.3705 - val_loss: 0.1548 - val_mae: 0.3177
# Epoch 188/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2999 - mae: 0.3974 - val_loss: 0.1542 - val_mae: 0.3110
# Epoch 189/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2852 - mae: 0.3761 - val_loss: 0.2017 - val_mae: 0.3570
# Epoch 190/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2994 - mae: 0.3844 - val_loss: 0.2406 - val_mae: 0.3953
# Epoch 191/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2888 - mae: 0.3866 - val_loss: 0.1890 - val_mae: 0.3454
# Epoch 192/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2679 - mae: 0.3676 - val_loss: 0.1724 - val_mae: 0.3262
# Epoch 193/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2618 - mae: 0.3606 - val_loss: 0.2020 - val_mae: 0.3528
# Epoch 194/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2671 - mae: 0.3655 - val_loss: 0.1554 - val_mae: 0.3139
# Epoch 195/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2625 - mae: 0.3628 - val_loss: 0.1516 - val_mae: 0.3103
# Epoch 196/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2572 - mae: 0.3558 - val_loss: 0.1570 - val_mae: 0.3116
# Epoch 197/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2600 - mae: 0.3577 - val_loss: 0.1722 - val_mae: 0.3253
# Epoch 198/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2667 - mae: 0.3662 - val_loss: 0.1777 - val_mae: 0.3314
# Epoch 199/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2615 - mae: 0.3603 - val_loss: 0.1588 - val_mae: 0.3148
# Epoch 200/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2593 - mae: 0.3588 - val_loss: 0.1509 - val_mae: 0.3101
# Epoch 201/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2666 - mae: 0.3620 - val_loss: 0.1696 - val_mae: 0.3206
# Epoch 202/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2668 - mae: 0.3676 - val_loss: 0.1554 - val_mae: 0.3140
# Epoch 203/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2587 - mae: 0.3622 - val_loss: 0.1578 - val_mae: 0.3184
# Epoch 204/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2622 - mae: 0.3613 - val_loss: 0.1555 - val_mae: 0.3090
# Epoch 205/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2564 - mae: 0.3562 - val_loss: 0.1590 - val_mae: 0.3164
# Epoch 206/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2596 - mae: 0.3586 - val_loss: 0.1705 - val_mae: 0.3253
# Epoch 207/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2596 - mae: 0.3601 - val_loss: 0.1587 - val_mae: 0.3135
# Epoch 208/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2599 - mae: 0.3580 - val_loss: 0.1525 - val_mae: 0.3082
# Epoch 209/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2607 - mae: 0.3579 - val_loss: 0.1544 - val_mae: 0.3145
# Epoch 210/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2651 - mae: 0.3649 - val_loss: 0.1570 - val_mae: 0.3193
# Epoch 211/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2721 - mae: 0.3693 - val_loss: 0.1574 - val_mae: 0.3091
# Epoch 212/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2857 - mae: 0.3764 - val_loss: 0.1551 - val_mae: 0.3141
# Epoch 213/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2833 - mae: 0.3793 - val_loss: 0.1625 - val_mae: 0.3246
# Epoch 214/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2725 - mae: 0.3716 - val_loss: 0.1591 - val_mae: 0.3193
# Epoch 215/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2667 - mae: 0.3634 - val_loss: 0.1527 - val_mae: 0.3078
# Epoch 216/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2628 - mae: 0.3616 - val_loss: 0.1533 - val_mae: 0.3122
# Epoch 217/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2609 - mae: 0.3560 - val_loss: 0.1687 - val_mae: 0.3220
# Epoch 218/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2659 - mae: 0.3616 - val_loss: 0.1849 - val_mae: 0.3377
# Epoch 219/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2642 - mae: 0.3596 - val_loss: 0.2021 - val_mae: 0.3551
# Epoch 220/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2680 - mae: 0.3657 - val_loss: 0.1940 - val_mae: 0.3493
# Epoch 221/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2713 - mae: 0.3725 - val_loss: 0.1615 - val_mae: 0.3148
# Epoch 222/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2589 - mae: 0.3569 - val_loss: 0.1546 - val_mae: 0.3115
# Epoch 223/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2579 - mae: 0.3590 - val_loss: 0.1591 - val_mae: 0.3139
# Epoch 224/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2612 - mae: 0.3609 - val_loss: 0.1560 - val_mae: 0.3147
# Epoch 225/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2617 - mae: 0.3583 - val_loss: 0.1514 - val_mae: 0.3081
# Epoch 226/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2606 - mae: 0.3582 - val_loss: 0.1597 - val_mae: 0.3130
# Epoch 227/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2629 - mae: 0.3595 - val_loss: 0.1630 - val_mae: 0.3207
# Epoch 228/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2589 - mae: 0.3593 - val_loss: 0.1519 - val_mae: 0.3105
# Epoch 229/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2590 - mae: 0.3574 - val_loss: 0.1657 - val_mae: 0.3173
# Epoch 230/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2604 - mae: 0.3590 - val_loss: 0.1533 - val_mae: 0.3111
# Epoch 231/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2595 - mae: 0.3596 - val_loss: 0.1685 - val_mae: 0.3232
# Epoch 232/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2656 - mae: 0.3655 - val_loss: 0.1570 - val_mae: 0.3213
# Epoch 233/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2674 - mae: 0.3673 - val_loss: 0.1560 - val_mae: 0.3153
# Epoch 234/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2741 - mae: 0.3722 - val_loss: 0.1561 - val_mae: 0.3155
# Epoch 235/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2652 - mae: 0.3670 - val_loss: 0.1552 - val_mae: 0.3131
# Epoch 236/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2602 - mae: 0.3594 - val_loss: 0.1675 - val_mae: 0.3228
# Epoch 237/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2716 - mae: 0.3703 - val_loss: 0.1962 - val_mae: 0.3515
# Epoch 238/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2769 - mae: 0.3796 - val_loss: 0.1669 - val_mae: 0.3197
# Epoch 239/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2609 - mae: 0.3598 - val_loss: 0.1573 - val_mae: 0.3145
# Epoch 240/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2582 - mae: 0.3600 - val_loss: 0.1559 - val_mae: 0.3097
# Epoch 241/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2620 - mae: 0.3588 - val_loss: 0.1697 - val_mae: 0.3205
# Epoch 242/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2626 - mae: 0.3560 - val_loss: 0.1983 - val_mae: 0.3529
# Epoch 243/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2652 - mae: 0.3646 - val_loss: 0.1551 - val_mae: 0.3098
# Epoch 244/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2584 - mae: 0.3578 - val_loss: 0.1632 - val_mae: 0.3171
# Epoch 245/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2598 - mae: 0.3597 - val_loss: 0.1582 - val_mae: 0.3148
# Epoch 246/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2689 - mae: 0.3700 - val_loss: 0.1580 - val_mae: 0.3179
# Epoch 247/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2622 - mae: 0.3603 - val_loss: 0.1772 - val_mae: 0.3276
# Epoch 248/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2744 - mae: 0.3731 - val_loss: 0.1592 - val_mae: 0.3205
# Epoch 249/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2696 - mae: 0.3698 - val_loss: 0.1532 - val_mae: 0.3132
# Epoch 250/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2751 - mae: 0.3723 - val_loss: 0.1527 - val_mae: 0.3128
# Epoch 251/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2639 - mae: 0.3644 - val_loss: 0.1534 - val_mae: 0.3092
# Epoch 252/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2680 - mae: 0.3658 - val_loss: 0.1955 - val_mae: 0.3500
# Epoch 253/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2759 - mae: 0.3660 - val_loss: 0.1915 - val_mae: 0.3414
# Epoch 254/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2724 - mae: 0.3648 - val_loss: 0.1700 - val_mae: 0.3255
# Epoch 255/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2687 - mae: 0.3686 - val_loss: 0.1541 - val_mae: 0.3117
# Epoch 256/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2817 - mae: 0.3789 - val_loss: 0.1573 - val_mae: 0.3129
# Epoch 257/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2768 - mae: 0.3734 - val_loss: 0.1691 - val_mae: 0.3223
# Epoch 258/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2954 - mae: 0.3899 - val_loss: 0.1730 - val_mae: 0.3311
# Epoch 259/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2733 - mae: 0.3672 - val_loss: 0.1842 - val_mae: 0.3388
# Epoch 260/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2702 - mae: 0.3657 - val_loss: 0.2126 - val_mae: 0.3659
# Epoch 261/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2738 - mae: 0.3747 - val_loss: 0.1972 - val_mae: 0.3529
# Epoch 262/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2731 - mae: 0.3686 - val_loss: 0.1743 - val_mae: 0.3297
# Epoch 263/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2663 - mae: 0.3635 - val_loss: 0.1861 - val_mae: 0.3397
# Epoch 264/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2662 - mae: 0.3648 - val_loss: 0.2055 - val_mae: 0.3589
# Epoch 265/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2777 - mae: 0.3835 - val_loss: 0.2016 - val_mae: 0.3517
# Epoch 266/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2627 - mae: 0.3662 - val_loss: 0.1593 - val_mae: 0.3134
# Epoch 267/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2586 - mae: 0.3604 - val_loss: 0.1538 - val_mae: 0.3136
# Epoch 268/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2646 - mae: 0.3638 - val_loss: 0.1551 - val_mae: 0.3092
# Epoch 269/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2614 - mae: 0.3579 - val_loss: 0.1595 - val_mae: 0.3143
# Epoch 270/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2610 - mae: 0.3594 - val_loss: 0.1541 - val_mae: 0.3103
# Epoch 271/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2612 - mae: 0.3582 - val_loss: 0.1777 - val_mae: 0.3312
# Epoch 272/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2661 - mae: 0.3663 - val_loss: 0.1525 - val_mae: 0.3132
# Epoch 273/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2801 - mae: 0.3782 - val_loss: 0.1514 - val_mae: 0.3075
# Epoch 274/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2729 - mae: 0.3739 - val_loss: 0.1558 - val_mae: 0.3166
# Epoch 275/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2585 - mae: 0.3599 - val_loss: 0.1525 - val_mae: 0.3119
# Epoch 276/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2573 - mae: 0.3586 - val_loss: 0.1699 - val_mae: 0.3230
# Epoch 277/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2601 - mae: 0.3596 - val_loss: 0.1535 - val_mae: 0.3115
# Epoch 278/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2637 - mae: 0.3598 - val_loss: 0.1554 - val_mae: 0.3101
# Epoch 279/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2580 - mae: 0.3592 - val_loss: 0.1538 - val_mae: 0.3118
# Epoch 280/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2612 - mae: 0.3626 - val_loss: 0.1547 - val_mae: 0.3163
# Epoch 281/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2607 - mae: 0.3594 - val_loss: 0.1599 - val_mae: 0.3147
# Epoch 282/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2692 - mae: 0.3677 - val_loss: 0.1805 - val_mae: 0.3326
# Epoch 283/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2601 - mae: 0.3626 - val_loss: 0.1560 - val_mae: 0.3139
# Epoch 284/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2588 - mae: 0.3599 - val_loss: 0.1616 - val_mae: 0.3158
# Epoch 285/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2641 - mae: 0.3646 - val_loss: 0.1767 - val_mae: 0.3295
# Epoch 286/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2651 - mae: 0.3618 - val_loss: 0.1769 - val_mae: 0.3283
# Epoch 287/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2620 - mae: 0.3580 - val_loss: 0.2297 - val_mae: 0.3848
# Epoch 288/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2874 - mae: 0.3817 - val_loss: 0.2055 - val_mae: 0.3588
# Epoch 289/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2766 - mae: 0.3703 - val_loss: 0.1840 - val_mae: 0.3355
# Epoch 290/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2596 - mae: 0.3604 - val_loss: 0.1688 - val_mae: 0.3231
# Epoch 291/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2747 - mae: 0.3712 - val_loss: 0.1856 - val_mae: 0.3378
# Epoch 292/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2828 - mae: 0.3853 - val_loss: 0.1669 - val_mae: 0.3222
# Epoch 293/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2663 - mae: 0.3639 - val_loss: 0.1522 - val_mae: 0.3077
# Epoch 294/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2734 - mae: 0.3775 - val_loss: 0.1556 - val_mae: 0.3159
# Epoch 295/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2693 - mae: 0.3663 - val_loss: 0.1531 - val_mae: 0.3122
# Epoch 296/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2617 - mae: 0.3602 - val_loss: 0.1689 - val_mae: 0.3215
# Epoch 297/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2617 - mae: 0.3583 - val_loss: 0.1644 - val_mae: 0.3206
# Epoch 298/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2947 - mae: 0.3920 - val_loss: 0.1547 - val_mae: 0.3154
# Epoch 299/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2774 - mae: 0.3824 - val_loss: 0.1533 - val_mae: 0.3128
# Epoch 300/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2611 - mae: 0.3609 - val_loss: 0.1690 - val_mae: 0.3222
# Epoch 301/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2617 - mae: 0.3620 - val_loss: 0.1620 - val_mae: 0.3153
# Epoch 302/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2623 - mae: 0.3636 - val_loss: 0.1609 - val_mae: 0.3163
# Epoch 303/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2593 - mae: 0.3591 - val_loss: 0.1649 - val_mae: 0.3202
# Epoch 304/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2621 - mae: 0.3600 - val_loss: 0.1546 - val_mae: 0.3080
# Epoch 305/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2575 - mae: 0.3580 - val_loss: 0.1687 - val_mae: 0.3244
# Epoch 306/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2644 - mae: 0.3648 - val_loss: 0.1941 - val_mae: 0.3492
# Epoch 307/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2669 - mae: 0.3674 - val_loss: 0.1516 - val_mae: 0.3107
# Epoch 308/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2606 - mae: 0.3593 - val_loss: 0.1687 - val_mae: 0.3210
# Epoch 309/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2725 - mae: 0.3713 - val_loss: 0.1616 - val_mae: 0.3130
# Epoch 310/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2578 - mae: 0.3560 - val_loss: 0.1555 - val_mae: 0.3111
# Epoch 311/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2597 - mae: 0.3581 - val_loss: 0.1560 - val_mae: 0.3117
# Epoch 312/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2633 - mae: 0.3587 - val_loss: 0.1521 - val_mae: 0.3114
# Epoch 313/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2601 - mae: 0.3592 - val_loss: 0.1536 - val_mae: 0.3111
# Epoch 314/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2623 - mae: 0.3599 - val_loss: 0.1559 - val_mae: 0.3143
# Epoch 315/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2614 - mae: 0.3581 - val_loss: 0.1562 - val_mae: 0.3126
# Epoch 316/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2651 - mae: 0.3641 - val_loss: 0.1520 - val_mae: 0.3094
# Epoch 317/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2602 - mae: 0.3617 - val_loss: 0.1536 - val_mae: 0.3149
# Epoch 318/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2762 - mae: 0.3714 - val_loss: 0.1652 - val_mae: 0.3266
# Epoch 319/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2634 - mae: 0.3590 - val_loss: 0.1577 - val_mae: 0.3183
# Epoch 320/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2632 - mae: 0.3693 - val_loss: 0.1634 - val_mae: 0.3169
# Epoch 321/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2608 - mae: 0.3618 - val_loss: 0.1755 - val_mae: 0.3303
# Epoch 322/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2628 - mae: 0.3640 - val_loss: 0.1584 - val_mae: 0.3201
# Epoch 323/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2604 - mae: 0.3591 - val_loss: 0.1750 - val_mae: 0.3270
# Epoch 324/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2609 - mae: 0.3591 - val_loss: 0.1670 - val_mae: 0.3200
# Epoch 325/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2679 - mae: 0.3655 - val_loss: 0.1559 - val_mae: 0.3118
# Epoch 326/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2634 - mae: 0.3639 - val_loss: 0.1583 - val_mae: 0.3134
# Epoch 327/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2596 - mae: 0.3584 - val_loss: 0.1661 - val_mae: 0.3187
# Epoch 328/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2640 - mae: 0.3657 - val_loss: 0.1607 - val_mae: 0.3181
# Epoch 329/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2641 - mae: 0.3662 - val_loss: 0.1592 - val_mae: 0.3142
# Epoch 330/500
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2796 - mae: 0.3731 - val_loss: 0.2074 - val_mae: 0.3580
# Epoch 331/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3032 - mae: 0.4022 - val_loss: 0.2224 - val_mae: 0.3783
# Epoch 332/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2821 - mae: 0.3784 - val_loss: 0.1860 - val_mae: 0.3389
# Epoch 333/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2671 - mae: 0.3630 - val_loss: 0.1728 - val_mae: 0.3258
# Epoch 334/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2731 - mae: 0.3691 - val_loss: 0.2232 - val_mae: 0.3771
# Epoch 335/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2775 - mae: 0.3735 - val_loss: 0.1831 - val_mae: 0.3387
# Epoch 336/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2649 - mae: 0.3652 - val_loss: 0.1908 - val_mae: 0.3426
# Epoch 337/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2694 - mae: 0.3673 - val_loss: 0.1550 - val_mae: 0.3110
# Epoch 338/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2595 - mae: 0.3587 - val_loss: 0.1554 - val_mae: 0.3141
# Epoch 339/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2627 - mae: 0.3600 - val_loss: 0.1543 - val_mae: 0.3134
# Epoch 340/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2628 - mae: 0.3630 - val_loss: 0.1533 - val_mae: 0.3113
# Epoch 341/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2721 - mae: 0.3731 - val_loss: 0.1920 - val_mae: 0.3514
# Epoch 342/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2893 - mae: 0.3821 - val_loss: 0.2153 - val_mae: 0.3729
# Epoch 343/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2956 - mae: 0.3892 - val_loss: 0.1519 - val_mae: 0.3121
# Epoch 344/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2642 - mae: 0.3604 - val_loss: 0.1591 - val_mae: 0.3102
# Epoch 345/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2594 - mae: 0.3574 - val_loss: 0.1628 - val_mae: 0.3169
# Epoch 346/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2644 - mae: 0.3653 - val_loss: 0.1689 - val_mae: 0.3240
# Epoch 347/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2598 - mae: 0.3601 - val_loss: 0.1541 - val_mae: 0.3150
# Epoch 348/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2636 - mae: 0.3616 - val_loss: 0.1628 - val_mae: 0.3152
# Epoch 349/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2602 - mae: 0.3570 - val_loss: 0.1697 - val_mae: 0.3262
# Epoch 350/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2678 - mae: 0.3658 - val_loss: 0.1547 - val_mae: 0.3115
# Epoch 351/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2605 - mae: 0.3573 - val_loss: 0.1545 - val_mae: 0.3088
# Epoch 352/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2596 - mae: 0.3584 - val_loss: 0.1543 - val_mae: 0.3154
# Epoch 353/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2928 - mae: 0.3841 - val_loss: 0.1722 - val_mae: 0.3331
# Epoch 354/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3173 - mae: 0.4073 - val_loss: 0.1539 - val_mae: 0.3153
# Epoch 355/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2948 - mae: 0.3933 - val_loss: 0.1681 - val_mae: 0.3244
# Epoch 356/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2698 - mae: 0.3735 - val_loss: 0.1698 - val_mae: 0.3225
# Epoch 357/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2623 - mae: 0.3636 - val_loss: 0.1732 - val_mae: 0.3268
# Epoch 358/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2631 - mae: 0.3649 - val_loss: 0.1713 - val_mae: 0.3254
# Epoch 359/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2638 - mae: 0.3629 - val_loss: 0.1590 - val_mae: 0.3142
# Epoch 360/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2591 - mae: 0.3593 - val_loss: 0.1522 - val_mae: 0.3119
# Epoch 361/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2630 - mae: 0.3613 - val_loss: 0.1587 - val_mae: 0.3141
# Epoch 362/500
# ...
# Epoch 381/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2645 - mae: 0.3641 - val_loss: 0.1703 - val_mae: 0.3249
# Epoch 382/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2680 - mae: 0.3653 - val_loss: 0.1530 - val_mae: 0.3107
# Epoch 383/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2588 - mae: 0.3565 - val_loss: 0.1594 - val_mae: 0.3144
# Epoch 384/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2588 - mae: 0.3585 - val_loss: 0.1546 - val_mae: 0.3119
# Epoch 385/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2598 - mae: 0.3597 - val_loss: 0.1836 - val_mae: 0.3337
# Epoch 386/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2605 - mae: 0.3618 - val_loss: 0.1558 - val_mae: 0.3137
# Epoch 387/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2614 - mae: 0.3603 - val_loss: 0.1586 - val_mae: 0.3141
# Epoch 388/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2669 - mae: 0.3640 - val_loss: 0.1842 - val_mae: 0.3352
# Epoch 389/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2840 - mae: 0.3842 - val_loss: 0.1711 - val_mae: 0.3264
# Epoch 390/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2631 - mae: 0.3615 - val_loss: 0.1958 - val_mae: 0.3458
# Epoch 391/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2712 - mae: 0.3707 - val_loss: 0.1909 - val_mae: 0.3440
# Epoch 392/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2680 - mae: 0.3659 - val_loss: 0.1554 - val_mae: 0.3115
# Epoch 393/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2692 - mae: 0.3658 - val_loss: 0.1568 - val_mae: 0.3109
# Epoch 394/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2739 - mae: 0.3778 - val_loss: 0.1617 - val_mae: 0.3202
# Epoch 395/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2817 - mae: 0.3758 - val_loss: 0.2007 - val_mae: 0.3520
# Epoch 396/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2717 - mae: 0.3671 - val_loss: 0.1881 - val_mae: 0.3425
# Epoch 397/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2695 - mae: 0.3645 - val_loss: 0.1707 - val_mae: 0.3252
# Epoch 398/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2697 - mae: 0.3675 - val_loss: 0.1686 - val_mae: 0.3233
# Epoch 399/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2626 - mae: 0.3615 - val_loss: 0.1958 - val_mae: 0.3491
# Epoch 400/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2763 - mae: 0.3775 - val_loss: 0.1712 - val_mae: 0.3250
# Epoch 401/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2671 - mae: 0.3640 - val_loss: 0.1596 - val_mae: 0.3157
# Epoch 402/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2614 - mae: 0.3565 - val_loss: 0.1803 - val_mae: 0.3328
# Epoch 403/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2703 - mae: 0.3717 - val_loss: 0.1636 - val_mae: 0.3204
# Epoch 404/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2630 - mae: 0.3626 - val_loss: 0.1505 - val_mae: 0.3083
# Epoch 405/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2593 - mae: 0.3586 - val_loss: 0.1515 - val_mae: 0.3069
# Epoch 406/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2613 - mae: 0.3612 - val_loss: 0.1536 - val_mae: 0.3118
# Epoch 407/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2578 - mae: 0.3580 - val_loss: 0.1668 - val_mae: 0.3198
# Epoch 408/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2621 - mae: 0.3593 - val_loss: 0.1541 - val_mae: 0.3105
# Epoch 409/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2602 - mae: 0.3601 - val_loss: 0.1922 - val_mae: 0.3462
# Epoch 410/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2681 - mae: 0.3675 - val_loss: 0.1896 - val_mae: 0.3436
# Epoch 411/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2629 - mae: 0.3616 - val_loss: 0.1657 - val_mae: 0.3197
# Epoch 412/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2670 - mae: 0.3696 - val_loss: 0.1577 - val_mae: 0.3184
# Epoch 413/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2599 - mae: 0.3598 - val_loss: 0.1561 - val_mae: 0.3129
# Epoch 414/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2627 - mae: 0.3592 - val_loss: 0.1531 - val_mae: 0.3091
# Epoch 415/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2591 - mae: 0.3606 - val_loss: 0.1568 - val_mae: 0.3179
# Epoch 416/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2672 - mae: 0.3669 - val_loss: 0.1547 - val_mae: 0.3154
# Epoch 417/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2630 - mae: 0.3641 - val_loss: 0.1794 - val_mae: 0.3320
# Epoch 418/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2617 - mae: 0.3551 - val_loss: 0.2111 - val_mae: 0.3621
# Epoch 419/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2650 - mae: 0.3688 - val_loss: 0.1522 - val_mae: 0.3096
# Epoch 420/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2602 - mae: 0.3597 - val_loss: 0.1537 - val_mae: 0.3118
# Epoch 421/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2598 - mae: 0.3614 - val_loss: 0.1545 - val_mae: 0.3137
# Epoch 422/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2660 - mae: 0.3677 - val_loss: 0.1574 - val_mae: 0.3127
# Epoch 423/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2646 - mae: 0.3615 - val_loss: 0.1850 - val_mae: 0.3390
# Epoch 424/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2660 - mae: 0.3649 - val_loss: 0.1767 - val_mae: 0.3271
# Epoch 425/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2644 - mae: 0.3647 - val_loss: 0.1603 - val_mae: 0.3169
# Epoch 426/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2596 - mae: 0.3603 - val_loss: 0.1577 - val_mae: 0.3125
# Epoch 427/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2598 - mae: 0.3602 - val_loss: 0.1763 - val_mae: 0.3299
# Epoch 428/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2710 - mae: 0.3672 - val_loss: 0.1969 - val_mae: 0.3516
# Epoch 429/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2707 - mae: 0.3651 - val_loss: 0.1822 - val_mae: 0.3359
# Epoch 430/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2815 - mae: 0.3876 - val_loss: 0.1645 - val_mae: 0.3205
# Epoch 431/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2602 - mae: 0.3614 - val_loss: 0.1535 - val_mae: 0.3084
# Epoch 432/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2594 - mae: 0.3600 - val_loss: 0.1532 - val_mae: 0.3119
# Epoch 433/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2628 - mae: 0.3626 - val_loss: 0.1563 - val_mae: 0.3133
# Epoch 434/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2584 - mae: 0.3573 - val_loss: 0.1554 - val_mae: 0.3120
# Epoch 435/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2564 - mae: 0.3577 - val_loss: 0.1518 - val_mae: 0.3089
# Epoch 436/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2612 - mae: 0.3612 - val_loss: 0.1519 - val_mae: 0.3100
# Epoch 437/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2590 - mae: 0.3600 - val_loss: 0.1599 - val_mae: 0.3143
# Epoch 438/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2626 - mae: 0.3620 - val_loss: 0.1668 - val_mae: 0.3192
# Epoch 439/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2699 - mae: 0.3707 - val_loss: 0.1512 - val_mae: 0.3129
# Epoch 440/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2584 - mae: 0.3596 - val_loss: 0.1566 - val_mae: 0.3134
# Epoch 441/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2618 - mae: 0.3614 - val_loss: 0.1582 - val_mae: 0.3149
# Epoch 442/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2637 - mae: 0.3632 - val_loss: 0.1545 - val_mae: 0.3140
# Epoch 443/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2564 - mae: 0.3584 - val_loss: 0.1525 - val_mae: 0.3112
# Epoch 444/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2637 - mae: 0.3661 - val_loss: 0.1530 - val_mae: 0.3114
# Epoch 445/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2732 - mae: 0.3756 - val_loss: 0.1550 - val_mae: 0.3146
# Epoch 446/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2685 - mae: 0.3713 - val_loss: 0.1870 - val_mae: 0.3397
# Epoch 447/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2668 - mae: 0.3658 - val_loss: 0.1952 - val_mae: 0.3494
# Epoch 448/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2636 - mae: 0.3620 - val_loss: 0.1594 - val_mae: 0.3144
# Epoch 449/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2699 - mae: 0.3666 - val_loss: 0.1515 - val_mae: 0.3094
# Epoch 450/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2672 - mae: 0.3659 - val_loss: 0.1557 - val_mae: 0.3111
# Epoch 451/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2614 - mae: 0.3619 - val_loss: 0.1655 - val_mae: 0.3190
# Epoch 452/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2699 - mae: 0.3691 - val_loss: 0.1547 - val_mae: 0.3122
# Epoch 453/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2615 - mae: 0.3627 - val_loss: 0.1524 - val_mae: 0.3117
# Epoch 454/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2616 - mae: 0.3625 - val_loss: 0.1522 - val_mae: 0.3107
# Epoch 455/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2586 - mae: 0.3562 - val_loss: 0.1527 - val_mae: 0.3098
# Epoch 456/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2589 - mae: 0.3594 - val_loss: 0.1533 - val_mae: 0.3142
# Epoch 457/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2612 - mae: 0.3602 - val_loss: 0.1691 - val_mae: 0.3230
# Epoch 458/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2653 - mae: 0.3644 - val_loss: 0.1664 - val_mae: 0.3190
# Epoch 459/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2586 - mae: 0.3578 - val_loss: 0.1550 - val_mae: 0.3121
# Epoch 460/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2586 - mae: 0.3579 - val_loss: 0.1530 - val_mae: 0.3097
# Epoch 461/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2604 - mae: 0.3590 - val_loss: 0.1569 - val_mae: 0.3104
# Epoch 462/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2595 - mae: 0.3575 - val_loss: 0.1948 - val_mae: 0.3467
# Epoch 463/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2703 - mae: 0.3699 - val_loss: 0.1720 - val_mae: 0.3258
# Epoch 464/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2729 - mae: 0.3713 - val_loss: 0.1790 - val_mae: 0.3332
# Epoch 465/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2642 - mae: 0.3673 - val_loss: 0.1541 - val_mae: 0.3143
# Epoch 466/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2602 - mae: 0.3583 - val_loss: 0.1692 - val_mae: 0.3213
# Epoch 467/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2590 - mae: 0.3596 - val_loss: 0.1627 - val_mae: 0.3177
# Epoch 468/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2630 - mae: 0.3625 - val_loss: 0.1696 - val_mae: 0.3231
# Epoch 469/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2593 - mae: 0.3575 - val_loss: 0.1562 - val_mae: 0.3103
# Epoch 470/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2577 - mae: 0.3563 - val_loss: 0.1537 - val_mae: 0.3139
# Epoch 471/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2604 - mae: 0.3631 - val_loss: 0.1526 - val_mae: 0.3117
# Epoch 472/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2586 - mae: 0.3580 - val_loss: 0.1512 - val_mae: 0.3089
# Epoch 473/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2700 - mae: 0.3742 - val_loss: 0.1885 - val_mae: 0.3412
# Epoch 474/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2883 - mae: 0.3806 - val_loss: 0.1928 - val_mae: 0.3464
# Epoch 475/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2601 - mae: 0.3596 - val_loss: 0.2284 - val_mae: 0.3796
# Epoch 476/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2941 - mae: 0.3914 - val_loss: 0.1646 - val_mae: 0.3205
# Epoch 477/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2829 - mae: 0.3807 - val_loss: 0.1783 - val_mae: 0.3345
# Epoch 478/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2637 - mae: 0.3699 - val_loss: 0.1526 - val_mae: 0.3115
# Epoch 479/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2637 - mae: 0.3675 - val_loss: 0.1702 - val_mae: 0.3319
# Epoch 480/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2669 - mae: 0.3656 - val_loss: 0.1526 - val_mae: 0.3106
# Epoch 481/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2731 - mae: 0.3727 - val_loss: 0.1719 - val_mae: 0.3241
# Epoch 482/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2666 - mae: 0.3646 - val_loss: 0.1926 - val_mae: 0.3449
# Epoch 483/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2778 - mae: 0.3725 - val_loss: 0.1741 - val_mae: 0.3270
# Epoch 484/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2589 - mae: 0.3585 - val_loss: 0.1686 - val_mae: 0.3220
# Epoch 485/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2677 - mae: 0.3655 - val_loss: 0.1536 - val_mae: 0.3081
# Epoch 486/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2732 - mae: 0.3770 - val_loss: 0.1648 - val_mae: 0.3297
# Epoch 487/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2659 - mae: 0.3667 - val_loss: 0.1546 - val_mae: 0.3159
# Epoch 488/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2584 - mae: 0.3568 - val_loss: 0.1797 - val_mae: 0.3307
# Epoch 489/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2690 - mae: 0.3656 - val_loss: 0.1758 - val_mae: 0.3287
# Epoch 490/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2626 - mae: 0.3593 - val_loss: 0.1890 - val_mae: 0.3396
# Epoch 491/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2626 - mae: 0.3653 - val_loss: 0.1526 - val_mae: 0.3101
# Epoch 492/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2612 - mae: 0.3617 - val_loss: 0.1649 - val_mae: 0.3221
# Epoch 493/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2571 - mae: 0.3581 - val_loss: 0.1516 - val_mae: 0.3100
# Epoch 494/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2627 - mae: 0.3623 - val_loss: 0.1532 - val_mae: 0.3110
# Epoch 495/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2603 - mae: 0.3605 - val_loss: 0.1563 - val_mae: 0.3176
# Epoch 496/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2587 - mae: 0.3620 - val_loss: 0.1937 - val_mae: 0.3492
# Epoch 497/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2758 - mae: 0.3696 - val_loss: 0.2251 - val_mae: 0.3779
# Epoch 498/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2771 - mae: 0.3748 - val_loss: 0.1834 - val_mae: 0.3388
# Epoch 499/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2675 - mae: 0.3691 - val_loss: 0.1805 - val_mae: 0.3359
# Epoch 500/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2622 - mae: 0.3607 - val_loss: 0.1654 - val_mae: 0.3198

# %%
loss, mae = model.evaluate(x_test_scaled, test_y)
# Step4.2 Plot the learning curve
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.show()
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2360 - mae: 0.3618

# %%
predict_train = model.predict(x_train_scaled)
predict_test = model.predict(x_test_scaled)
# Root Mean Squared Error on train and test date
print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.4910482494940298
# RMSE on test data:  0.4857815637182578

# %% [markdown]
# Checking the plots it seems like we could have stopped training much earlier than we actually did. Let's define an early stopping criterion and rerun the same model with early stopping

# %%
callback = EarlyStopping(monitor="mae", patience=4)


model = Sequential()
model.add(Dense(64, activation="linear", input_shape=(x_train_scaled.shape[1],)))
model.add(Dense(128, activation="linear"))
model.add(Dense(64, activation="linear"))
model.add(Dense(32, activation="linear"))
model.add(Dense(1, activation="linear"))

model.compile(optimizer="adam", loss="mse", metrics="mae")


history = model.fit(
    x_train_scaled,
    train_y,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[callback],
)

loss, mae = model.evaluate(x_test_scaled, test_y)
# Step4.2 Plot the learning curve
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.show()
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 24ms/step - loss: 7.8616 - mae: 2.3548 - val_loss: 1.3927 - val_mae: 1.0406
# Epoch 2/500
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5781 - mae: 1.0575 - val_loss: 0.3461 - val_mae: 0.4447
# Epoch 3/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7814 - mae: 0.6939 - val_loss: 0.3397 - val_mae: 0.4515
# Epoch 4/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4584 - mae: 0.5258 - val_loss: 0.3626 - val_mae: 0.5012
# Epoch 5/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3703 - mae: 0.4459 - val_loss: 0.2419 - val_mae: 0.3829
# Epoch 6/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3555 - mae: 0.4270 - val_loss: 0.2303 - val_mae: 0.3826
# Epoch 7/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3381 - mae: 0.4283 - val_loss: 0.1998 - val_mae: 0.3491
# Epoch 8/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3250 - mae: 0.4072 - val_loss: 0.2047 - val_mae: 0.3570
# Epoch 9/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3156 - mae: 0.4078 - val_loss: 0.1923 - val_mae: 0.3428
# Epoch 10/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3069 - mae: 0.3958 - val_loss: 0.1937 - val_mae: 0.3443
# Epoch 11/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3013 - mae: 0.3931 - val_loss: 0.1895 - val_mae: 0.3400
# Epoch 12/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2980 - mae: 0.3900 - val_loss: 0.1848 - val_mae: 0.3331
# Epoch 13/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2923 - mae: 0.3830 - val_loss: 0.1891 - val_mae: 0.3344
# Epoch 14/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2894 - mae: 0.3824 - val_loss: 0.1796 - val_mae: 0.3295
# Epoch 15/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2861 - mae: 0.3784 - val_loss: 0.1859 - val_mae: 0.3355
# Epoch 16/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2846 - mae: 0.3772 - val_loss: 0.1792 - val_mae: 0.3269
# Epoch 17/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2811 - mae: 0.3734 - val_loss: 0.1945 - val_mae: 0.3443
# Epoch 18/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2808 - mae: 0.3761 - val_loss: 0.1764 - val_mae: 0.3261
# Epoch 19/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2788 - mae: 0.3728 - val_loss: 0.1808 - val_mae: 0.3271
# Epoch 20/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2797 - mae: 0.3707 - val_loss: 0.1762 - val_mae: 0.3243
# Epoch 21/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2818 - mae: 0.3724 - val_loss: 0.1763 - val_mae: 0.3253
# Epoch 22/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2749 - mae: 0.3696 - val_loss: 0.1765 - val_mae: 0.3216
# Epoch 23/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2739 - mae: 0.3673 - val_loss: 0.1841 - val_mae: 0.3324
# Epoch 24/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2735 - mae: 0.3697 - val_loss: 0.1705 - val_mae: 0.3221
# Epoch 25/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2715 - mae: 0.3692 - val_loss: 0.1743 - val_mae: 0.3219
# Epoch 26/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2687 - mae: 0.3658 - val_loss: 0.1674 - val_mae: 0.3179
# Epoch 27/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2690 - mae: 0.3661 - val_loss: 0.1751 - val_mae: 0.3245
# Epoch 28/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2683 - mae: 0.3651 - val_loss: 0.1738 - val_mae: 0.3238
# Epoch 29/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2665 - mae: 0.3659 - val_loss: 0.1647 - val_mae: 0.3195
# Epoch 30/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2704 - mae: 0.3675 - val_loss: 0.1945 - val_mae: 0.3413
# Epoch 31/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2683 - mae: 0.3671 - val_loss: 0.1714 - val_mae: 0.3228
# Epoch 32/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2670 - mae: 0.3656 - val_loss: 0.1765 - val_mae: 0.3222
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2357 - mae: 0.3591

# %%
predict_train = model.predict(x_train_scaled)
predict_test = model.predict(x_test_scaled)
# Root Mean Squared Error on train and test date
print("RMSE on train data: ", mean_squared_error(train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.49687845772957523
# RMSE on test data:  0.48544907814542876

# %% [markdown]
# If you encounter severe overfitting (another) common pracitce is to add Dropout layers. In Keras that is easily achivable by simply using: model.add(Dropout(dropout_value)). e.g. as done below

# %%
model = Sequential()
model.add(Dense(64, activation="linear", input_shape=(x_train_scaled.shape[1],)))
model.add(Dense(128, activation="linear"))

model.add(Dropout(0.5))

model.add(Dense(64, activation="linear"))
model.add(Dense(32, activation="linear"))
model.add(Dense(1, activation="linear"))

model.compile(optimizer="adam", loss="mse", metrics="mae")


history = model.fit(
    x_train_scaled,
    train_y,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[callback],
)

loss, mae = model.evaluate(x_test_scaled, test_y)
# Step4.2 Plot the learning curve
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.show()
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 23ms/step - loss: 7.6090 - mae: 2.2977 - val_loss: 2.8551 - val_mae: 1.4872
# Epoch 2/500
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2040 - mae: 1.1769 - val_loss: 0.5788 - val_mae: 0.5993
# Epoch 3/500
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1140 - mae: 0.8648 - val_loss: 0.3270 - val_mae: 0.4465
# Epoch 4/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7740 - mae: 0.6841 - val_loss: 0.2845 - val_mae: 0.4248
# Epoch 5/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7266 - mae: 0.6528 - val_loss: 0.2339 - val_mae: 0.3833
# Epoch 6/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6618 - mae: 0.6240 - val_loss: 0.2121 - val_mae: 0.3578
# Epoch 7/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7032 - mae: 0.6302 - val_loss: 0.2190 - val_mae: 0.3729
# Epoch 8/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6341 - mae: 0.5976 - val_loss: 0.2107 - val_mae: 0.3660
# Epoch 9/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5767 - mae: 0.5767 - val_loss: 0.2005 - val_mae: 0.3532
# Epoch 10/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5596 - mae: 0.5666 - val_loss: 0.1996 - val_mae: 0.3495
# Epoch 11/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5182 - mae: 0.5452 - val_loss: 0.1951 - val_mae: 0.3481
# Epoch 12/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5135 - mae: 0.5445 - val_loss: 0.1961 - val_mae: 0.3498
# Epoch 13/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5041 - mae: 0.5365 - val_loss: 0.1955 - val_mae: 0.3399
# Epoch 14/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4482 - mae: 0.5044 - val_loss: 0.1878 - val_mae: 0.3397
# Epoch 15/500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4797 - mae: 0.5232 - val_loss: 0.1975 - val_mae: 0.3431
# Epoch 16/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4593 - mae: 0.5234 - val_loss: 0.1854 - val_mae: 0.3363
# Epoch 17/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5021 - mae: 0.5267 - val_loss: 0.1854 - val_mae: 0.3340
# Epoch 18/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4533 - mae: 0.5107 - val_loss: 0.1819 - val_mae: 0.3327
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2440 - mae: 0.3467

# %% [markdown]
# # 4. Model building with images
#
# Now lets first try a simple regression simply with the images of the flats. Based on the above quick view of the images we can assume that a regression based on images might not yield the best results

# %%
img_train_x, img_test_x, img_train_y, img_test_y = train_test_split(
    train_images_flat, Y, test_size=0.25, random_state=0
)

# %%
# lets first run the model without early stopping but ionly for 100 epochs
epochs = 100

img_model = Sequential()

img_model.add(
    Conv2D(
        64,
        kernel_size=3,
        strides=2,
        activation="relu",
        padding="SAME",
        input_shape=train_images_flat[0].shape,
    )
)
img_model.add(MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))

img_model.add(
    Conv2D(
        128,
        kernel_size=3,
        strides=2,
        activation="relu",
        padding="SAME",
    )
)
img_model.add(MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))

img_model.add(
    Conv2D(
        64,
        kernel_size=3,
        strides=2,
        activation="relu",
        padding="SAME",
    )
)

img_model.add(Dropout(0.5))
img_model.add(Conv2D(64, kernel_size=3, strides=1, activation="relu", padding="SAME"))
img_model.add(Flatten())
img_model.add(Dense(32, activation="relu"))
img_model.add(Dense(1, activation="linear"))
img_model.compile(optimizer="adam", loss="mse", metrics=["mae"])

img_history = img_model.fit(
    img_train_x,
    img_train_y,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
)


loss, mae = img_model.evaluate(img_test_x, img_test_y)
# Step4.2 Plot the learning curve
plt.plot(img_history.history["loss"], label="train")
plt.plot(img_history.history["val_loss"], label="val")
plt.show()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 157ms/step - loss: 6.5466 - mae: 2.1217 - val_loss: 2.6633 - val_mae: 1.5483
# Epoch 2/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.6817 - mae: 1.1011 - val_loss: 0.3908 - val_mae: 0.4877
# Epoch 3/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.9794 - mae: 0.7774 - val_loss: 0.3933 - val_mae: 0.4985
# Epoch 4/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.8301 - mae: 0.7155 - val_loss: 0.4969 - val_mae: 0.5480
# Epoch 5/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7327 - mae: 0.6674 - val_loss: 0.6129 - val_mae: 0.6301
# Epoch 6/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.6529 - mae: 0.6487 - val_loss: 0.8867 - val_mae: 0.8004
# Epoch 7/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.6804 - mae: 0.6409 - val_loss: 0.6671 - val_mae: 0.6713
# Epoch 8/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.6982 - mae: 0.6366 - val_loss: 0.7276 - val_mae: 0.7114
# Epoch 9/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.6426 - mae: 0.6277 - val_loss: 0.5438 - val_mae: 0.5924
# Epoch 10/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.6210 - mae: 0.6019 - val_loss: 0.5971 - val_mae: 0.6311
# Epoch 11/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.5909 - mae: 0.5948 - val_loss: 0.8003 - val_mae: 0.7600
# Epoch 12/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.5918 - mae: 0.6122 - val_loss: 0.5200 - val_mae: 0.5854
# Epoch 13/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.5333 - mae: 0.5663 - val_loss: 0.5875 - val_mae: 0.6322
# Epoch 14/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.5673 - mae: 0.5843 - val_loss: 0.4668 - val_mae: 0.5506
# Epoch 15/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.5523 - mae: 0.5797 - val_loss: 0.9647 - val_mae: 0.8562
# Epoch 16/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.5530 - mae: 0.5720 - val_loss: 0.9617 - val_mae: 0.8552
# Epoch 17/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.5145 - mae: 0.5521 - val_loss: 0.9990 - val_mae: 0.8772
# Epoch 18/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.5021 - mae: 0.5382 - val_loss: 0.5708 - val_mae: 0.6292
# Epoch 19/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.4872 - mae: 0.5364 - val_loss: 0.8219 - val_mae: 0.7810
# Epoch 20/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.4826 - mae: 0.5435 - val_loss: 0.7608 - val_mae: 0.7467
# Epoch 21/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.4705 - mae: 0.5258 - val_loss: 0.8128 - val_mae: 0.7779
# Epoch 22/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.4386 - mae: 0.5089 - val_loss: 0.8456 - val_mae: 0.7968
# Epoch 23/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.4401 - mae: 0.5085 - val_loss: 0.6648 - val_mae: 0.6922
# Epoch 24/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.4445 - mae: 0.5187 - val_loss: 1.4586 - val_mae: 1.1064
# Epoch 25/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.5133 - mae: 0.5526 - val_loss: 1.2323 - val_mae: 1.0001
# Epoch 26/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.4566 - mae: 0.5174 - val_loss: 1.2616 - val_mae: 1.0135
# Epoch 27/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.4829 - mae: 0.5264 - val_loss: 0.8993 - val_mae: 0.8297
# Epoch 28/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.4497 - mae: 0.5171 - val_loss: 0.5977 - val_mae: 0.6510
# Epoch 29/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.4665 - mae: 0.5269 - val_loss: 1.2125 - val_mae: 0.9922
# Epoch 30/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.4243 - mae: 0.4972 - val_loss: 0.9779 - val_mae: 0.8739
# Epoch 31/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.4586 - mae: 0.5241 - val_loss: 1.5536 - val_mae: 1.1521
# Epoch 32/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.3738 - mae: 0.4575 - val_loss: 1.1683 - val_mae: 0.9732
# Epoch 33/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3965 - mae: 0.4785 - val_loss: 0.9654 - val_mae: 0.8700
# Epoch 34/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.3931 - mae: 0.4765 - val_loss: 0.9585 - val_mae: 0.8651
# Epoch 35/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.4021 - mae: 0.4898 - val_loss: 1.5110 - val_mae: 1.1336
# Epoch 36/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.3981 - mae: 0.4814 - val_loss: 1.2035 - val_mae: 0.9918
# Epoch 37/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3485 - mae: 0.4462 - val_loss: 1.5096 - val_mae: 1.1339
# Epoch 38/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.3542 - mae: 0.4523 - val_loss: 0.7010 - val_mae: 0.7214
# Epoch 39/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.4221 - mae: 0.5018 - val_loss: 1.5441 - val_mae: 1.1500
# Epoch 40/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3727 - mae: 0.4787 - val_loss: 0.8338 - val_mae: 0.7989
# Epoch 41/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.4396 - mae: 0.5214 - val_loss: 1.6035 - val_mae: 1.1750
# Epoch 42/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3362 - mae: 0.4409 - val_loss: 1.0058 - val_mae: 0.8920
# Epoch 43/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.3404 - mae: 0.4444 - val_loss: 1.1080 - val_mae: 0.9439
# Epoch 44/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2957 - mae: 0.4103 - val_loss: 1.1176 - val_mae: 0.9494
# Epoch 45/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3356 - mae: 0.4420 - val_loss: 0.6461 - val_mae: 0.6929
# Epoch 46/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.3096 - mae: 0.4246 - val_loss: 0.9341 - val_mae: 0.8537
# Epoch 47/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2792 - mae: 0.4027 - val_loss: 1.1023 - val_mae: 0.9444
# Epoch 48/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2761 - mae: 0.4010 - val_loss: 0.8517 - val_mae: 0.8120
# Epoch 49/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2555 - mae: 0.3915 - val_loss: 1.2602 - val_mae: 1.0183
# Epoch 50/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.2962 - mae: 0.4189 - val_loss: 0.9901 - val_mae: 0.8864
# Epoch 51/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.2466 - mae: 0.3837 - val_loss: 0.4756 - val_mae: 0.5822
# Epoch 52/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2412 - mae: 0.3769 - val_loss: 0.7382 - val_mae: 0.7433
# Epoch 53/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2331 - mae: 0.3677 - val_loss: 0.7660 - val_mae: 0.7574
# Epoch 54/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.1977 - mae: 0.3517 - val_loss: 0.7786 - val_mae: 0.7661
# Epoch 55/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1865 - mae: 0.3325 - val_loss: 0.6913 - val_mae: 0.7121
# Epoch 56/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2010 - mae: 0.3513 - val_loss: 0.3437 - val_mae: 0.4674
# Epoch 57/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.2458 - mae: 0.3889 - val_loss: 0.4477 - val_mae: 0.5550
# Epoch 58/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.2241 - mae: 0.3767 - val_loss: 0.4262 - val_mae: 0.5371
# Epoch 59/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.2051 - mae: 0.3505 - val_loss: 0.8634 - val_mae: 0.8122
# Epoch 60/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.1838 - mae: 0.3362 - val_loss: 0.7351 - val_mae: 0.7351
# Epoch 61/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2174 - mae: 0.3704 - val_loss: 0.3998 - val_mae: 0.5189
# Epoch 62/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.1691 - mae: 0.3236 - val_loss: 0.7945 - val_mae: 0.7755
# Epoch 63/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.1434 - mae: 0.3000 - val_loss: 0.6687 - val_mae: 0.6969
# Epoch 64/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.1345 - mae: 0.2834 - val_loss: 0.6911 - val_mae: 0.7095
# Epoch 65/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.1386 - mae: 0.2878 - val_loss: 0.5645 - val_mae: 0.6212
# Epoch 66/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.1427 - mae: 0.2945 - val_loss: 0.6367 - val_mae: 0.6743
# Epoch 67/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.1476 - mae: 0.2988 - val_loss: 0.5569 - val_mae: 0.6226
# Epoch 68/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.1400 - mae: 0.2953 - val_loss: 0.4963 - val_mae: 0.5791
# Epoch 69/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.1202 - mae: 0.2695 - val_loss: 0.4468 - val_mae: 0.5368
# Epoch 70/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.1087 - mae: 0.2577 - val_loss: 0.4483 - val_mae: 0.5454
# Epoch 71/100
# 10/10 [==============================] - 1s 139ms/step - loss: 0.1034 - mae: 0.2514 - val_loss: 0.5750 - val_mae: 0.6330
# Epoch 72/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.0981 - mae: 0.2449 - val_loss: 0.5581 - val_mae: 0.6181
# Epoch 73/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0828 - mae: 0.2247 - val_loss: 0.5097 - val_mae: 0.5830
# Epoch 74/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0919 - mae: 0.2376 - val_loss: 0.5451 - val_mae: 0.6053
# Epoch 75/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.0842 - mae: 0.2263 - val_loss: 0.3988 - val_mae: 0.4962
# Epoch 76/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0898 - mae: 0.2359 - val_loss: 0.5206 - val_mae: 0.5948
# Epoch 77/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.0835 - mae: 0.2238 - val_loss: 0.5192 - val_mae: 0.5861
# Epoch 78/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0815 - mae: 0.2238 - val_loss: 0.3594 - val_mae: 0.4699
# Epoch 79/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0775 - mae: 0.2175 - val_loss: 0.3714 - val_mae: 0.4825
# Epoch 80/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0859 - mae: 0.2312 - val_loss: 0.3568 - val_mae: 0.4707
# Epoch 81/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.0842 - mae: 0.2246 - val_loss: 0.4272 - val_mae: 0.5219
# Epoch 82/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0910 - mae: 0.2404 - val_loss: 0.4794 - val_mae: 0.5704
# Epoch 83/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0668 - mae: 0.2012 - val_loss: 0.3461 - val_mae: 0.4630
# Epoch 84/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0677 - mae: 0.2038 - val_loss: 0.3544 - val_mae: 0.4615
# Epoch 85/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.0588 - mae: 0.1876 - val_loss: 0.3648 - val_mae: 0.4734
# Epoch 86/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.0602 - mae: 0.1913 - val_loss: 0.4536 - val_mae: 0.5480
# Epoch 87/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0587 - mae: 0.1912 - val_loss: 0.3830 - val_mae: 0.4924
# Epoch 88/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0459 - mae: 0.1627 - val_loss: 0.3752 - val_mae: 0.4864
# Epoch 89/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0540 - mae: 0.1848 - val_loss: 0.3765 - val_mae: 0.4868
# Epoch 90/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0596 - mae: 0.1835 - val_loss: 0.3785 - val_mae: 0.4845
# Epoch 91/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.0523 - mae: 0.1762 - val_loss: 0.4359 - val_mae: 0.5292
# Epoch 92/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0578 - mae: 0.1800 - val_loss: 0.3571 - val_mae: 0.4761
# Epoch 93/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.0573 - mae: 0.1799 - val_loss: 0.3450 - val_mae: 0.4593
# Epoch 94/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0504 - mae: 0.1719 - val_loss: 0.3611 - val_mae: 0.4738
# Epoch 95/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0510 - mae: 0.1658 - val_loss: 0.3176 - val_mae: 0.4439
# Epoch 96/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0766 - mae: 0.2235 - val_loss: 0.3805 - val_mae: 0.4898
# Epoch 97/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0807 - mae: 0.2276 - val_loss: 0.2851 - val_mae: 0.4299
# Epoch 98/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0963 - mae: 0.2483 - val_loss: 0.3669 - val_mae: 0.4773
# Epoch 99/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0776 - mae: 0.2197 - val_loss: 0.6028 - val_mae: 0.6552
# Epoch 100/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.1084 - mae: 0.2683 - val_loss: 0.2614 - val_mae: 0.4076
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3084 - mae: 0.4206

# %%
predict_train = img_model.predict(img_train_x)
predict_test = img_model.predict(img_test_x)
print("RMSE on train data: ", mean_squared_error(img_train_y, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(img_test_y, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.28714762201980565
# RMSE on test data:  0.5553118593168862

# %% [markdown]
# Let's write a super ugly own train test split function to get ranom sample from the multiple datasets we have. There probably is a better solution for this, but this still works fine if you are carefull with the order of the arguments

# %%
def tt_split(*data, test_size=0.3, random_state=101):
    """Be aware of the input order of your arguments"""

    np.random.seed(random_state)

    len_list = [len(i) for i in data]
    if len(set(len_list)) != 1:
        raise ValueError("Lengths of input data must be identical")

    n = int(np.round(0.3 * len_list[0], 0))

    indexes = np.random.choice(len_list[0], n, replace=False)

    test_list = []
    train_list = []

    for i in range(len(data)):

        try:
            temp = data[i].values
        except AttributeError:
            temp = data[i]

        test_data = temp[indexes]
        train_data = temp[[i for i in range(len(temp)) if i not in indexes]]

        if type(data[i]) == pd.core.frame.DataFrame:
            test_data = pd.DataFrame(test_data, columns=data[i].columns)
            train_data = pd.DataFrame(train_data, columns=data[i].columns)

        test_list.append(test_data)
        train_list.append(train_data)

    return train_list, test_list


x, y = tt_split(train_df, train_images_host, train_images_flat, Y)

X_train, X_test, host_train, host_test, flat_train, flat_test, y_train, y_test = (
    x[0],
    y[0],
    x[1],
    y[1],
    x[2],
    y[2],
    x[3],
    y[3],
)

# %%
# model for Photo image
image_inputs = tf.keras.Input((64, 64, 3))

x_image = tf.keras.layers.Conv2D(
    filters=64, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(image_inputs)

x_image = (MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))(x_image)

x_image = tf.keras.layers.Conv2D(
    filters=128, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(x_image)

x_image = (MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))(x_image)

x_image = tf.keras.layers.Conv2D(
    filters=64, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(x_image)

x_image = tf.keras.layers.Flatten()(x_image)

x_image = tf.keras.layers.Dense(128, activation="relu")(x_image)

x_image = tf.keras.layers.Dropout(0.5)(x_image)


# model for Meta data
meta_inputs = tf.keras.Input(shape=((13,)))

x_meta = tf.keras.layers.Dense(13, activation="relu")(meta_inputs)

x_meta = tf.keras.layers.Dense(24, activation="relu")(x_meta)

x_meta = tf.keras.layers.Dense(12, activation="relu")(x_meta)


# concatenate the "two" models
x = tf.keras.layers.Concatenate(axis=1)([x_image, x_meta])

output = tf.keras.layers.Dense(1)(x)
multi_model = tf.keras.Model(inputs=[image_inputs, meta_inputs], outputs=output)

# %%
# compile the model

multi_model.compile(loss="mse", metrics=["mae"], optimizer="adam")

callback = EarlyStopping(monitor="loss", patience=10)

# train the model
multi_model_history = multi_model.fit(
    [host_train, X_train],
    y_train,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[callback],
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 166ms/step - loss: 11.6016 - mae: 2.8773 - val_loss: 1.6714 - val_mae: 0.9845
# Epoch 2/100
# 9/9 [==============================] - 1s 139ms/step - loss: 3.4917 - mae: 1.5803 - val_loss: 1.6929 - val_mae: 1.0412
# Epoch 3/100
# 9/9 [==============================] - 1s 139ms/step - loss: 2.0611 - mae: 1.1045 - val_loss: 0.8307 - val_mae: 0.6749
# Epoch 4/100
# 9/9 [==============================] - 1s 129ms/step - loss: 1.3368 - mae: 0.9091 - val_loss: 1.0673 - val_mae: 0.8115
# Epoch 5/100
# 9/9 [==============================] - 1s 138ms/step - loss: 1.2683 - mae: 0.8876 - val_loss: 0.7954 - val_mae: 0.6606
# Epoch 6/100
# 9/9 [==============================] - 1s 141ms/step - loss: 1.1129 - mae: 0.8088 - val_loss: 0.6925 - val_mae: 0.5948
# Epoch 7/100
# 9/9 [==============================] - 1s 142ms/step - loss: 0.9878 - mae: 0.7730 - val_loss: 0.6671 - val_mae: 0.5949
# Epoch 8/100
# 9/9 [==============================] - 1s 132ms/step - loss: 1.0010 - mae: 0.7730 - val_loss: 0.9399 - val_mae: 0.7632
# Epoch 9/100
# 9/9 [==============================] - 1s 133ms/step - loss: 0.9865 - mae: 0.7690 - val_loss: 0.6823 - val_mae: 0.6114
# Epoch 10/100
# 9/9 [==============================] - 1s 144ms/step - loss: 0.8661 - mae: 0.7329 - val_loss: 0.5993 - val_mae: 0.5466
# Epoch 11/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.8930 - mae: 0.7480 - val_loss: 0.5891 - val_mae: 0.5428
# Epoch 12/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.7195 - mae: 0.6758 - val_loss: 0.6141 - val_mae: 0.5639
# Epoch 13/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.7490 - mae: 0.6694 - val_loss: 0.5712 - val_mae: 0.5375
# Epoch 14/100
# 9/9 [==============================] - 1s 143ms/step - loss: 0.6873 - mae: 0.6436 - val_loss: 0.5398 - val_mae: 0.5148
# Epoch 15/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.7325 - mae: 0.6662 - val_loss: 0.6568 - val_mae: 0.6024
# Epoch 16/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.7667 - mae: 0.6827 - val_loss: 0.9405 - val_mae: 0.7810
# Epoch 17/100
# 9/9 [==============================] - 1s 139ms/step - loss: 0.7909 - mae: 0.7197 - val_loss: 0.5927 - val_mae: 0.5530
# Epoch 18/100
# 9/9 [==============================] - 1s 143ms/step - loss: 0.7050 - mae: 0.6540 - val_loss: 0.5369 - val_mae: 0.5143
# Epoch 19/100
# 9/9 [==============================] - 1s 142ms/step - loss: 0.6600 - mae: 0.6451 - val_loss: 0.5050 - val_mae: 0.4914
# Epoch 20/100
# 9/9 [==============================] - 1s 139ms/step - loss: 0.6106 - mae: 0.6022 - val_loss: 0.4651 - val_mae: 0.4602
# Epoch 21/100
# 9/9 [==============================] - 1s 134ms/step - loss: 0.5691 - mae: 0.5913 - val_loss: 0.4940 - val_mae: 0.4829
# Epoch 22/100
# 9/9 [==============================] - 1s 142ms/step - loss: 0.5454 - mae: 0.5788 - val_loss: 0.4641 - val_mae: 0.4587
# Epoch 23/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.5356 - mae: 0.5686 - val_loss: 0.4622 - val_mae: 0.4559
# Epoch 24/100
# 9/9 [==============================] - 1s 135ms/step - loss: 0.4595 - mae: 0.5263 - val_loss: 0.4494 - val_mae: 0.4469
# Epoch 25/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.4803 - mae: 0.5553 - val_loss: 0.4323 - val_mae: 0.4271
# Epoch 26/100
# 9/9 [==============================] - 1s 147ms/step - loss: 0.5013 - mae: 0.5526 - val_loss: 0.4147 - val_mae: 0.4108
# Epoch 27/100
# 9/9 [==============================] - 3s 341ms/step - loss: 0.4427 - mae: 0.5118 - val_loss: 0.4176 - val_mae: 0.4130
# Epoch 28/100
# 9/9 [==============================] - 4s 480ms/step - loss: 0.4318 - mae: 0.4994 - val_loss: 0.4203 - val_mae: 0.4157
# Epoch 29/100
# 9/9 [==============================] - 4s 466ms/step - loss: 0.4253 - mae: 0.5057 - val_loss: 0.4071 - val_mae: 0.4080
# Epoch 30/100
# 9/9 [==============================] - 4s 455ms/step - loss: 0.4016 - mae: 0.4823 - val_loss: 0.4130 - val_mae: 0.4166
# Epoch 31/100
# 9/9 [==============================] - 3s 370ms/step - loss: 0.3823 - mae: 0.4682 - val_loss: 0.3925 - val_mae: 0.3964
# Epoch 32/100
# 9/9 [==============================] - 5s 507ms/step - loss: 0.3442 - mae: 0.4520 - val_loss: 0.3902 - val_mae: 0.3924
# Epoch 33/100
# 9/9 [==============================] - 5s 491ms/step - loss: 0.3372 - mae: 0.4498 - val_loss: 0.3849 - val_mae: 0.3872
# Epoch 34/100
# 9/9 [==============================] - 2s 214ms/step - loss: 0.3207 - mae: 0.4263 - val_loss: 0.3933 - val_mae: 0.3938
# Epoch 35/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.3185 - mae: 0.4349 - val_loss: 0.3846 - val_mae: 0.3914
# Epoch 36/100
# 9/9 [==============================] - 1s 133ms/step - loss: 0.2784 - mae: 0.4000 - val_loss: 0.3728 - val_mae: 0.3769
# Epoch 37/100
# 9/9 [==============================] - 1s 139ms/step - loss: 0.2893 - mae: 0.4120 - val_loss: 0.3800 - val_mae: 0.3841
# Epoch 38/100
# 9/9 [==============================] - 1s 143ms/step - loss: 0.2886 - mae: 0.4158 - val_loss: 0.3823 - val_mae: 0.3859
# Epoch 39/100
# 9/9 [==============================] - 1s 140ms/step - loss: 0.2728 - mae: 0.4053 - val_loss: 0.3659 - val_mae: 0.3710
# Epoch 40/100
# 9/9 [==============================] - 1s 133ms/step - loss: 0.2614 - mae: 0.3907 - val_loss: 0.3780 - val_mae: 0.3899
# Epoch 41/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.2681 - mae: 0.3965 - val_loss: 0.3820 - val_mae: 0.3934
# Epoch 42/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.2818 - mae: 0.4103 - val_loss: 0.3800 - val_mae: 0.3824
# Epoch 43/100
# 9/9 [==============================] - 1s 148ms/step - loss: 0.2928 - mae: 0.4139 - val_loss: 0.4052 - val_mae: 0.4215
# Epoch 44/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.2521 - mae: 0.3842 - val_loss: 0.3622 - val_mae: 0.3667
# Epoch 45/100
# 9/9 [==============================] - 1s 142ms/step - loss: 0.2535 - mae: 0.3838 - val_loss: 0.3599 - val_mae: 0.3728
# Epoch 46/100
# 9/9 [==============================] - 1s 139ms/step - loss: 0.2386 - mae: 0.3762 - val_loss: 0.3521 - val_mae: 0.3653
# Epoch 47/100
# 9/9 [==============================] - 1s 134ms/step - loss: 0.2164 - mae: 0.3565 - val_loss: 0.3586 - val_mae: 0.3733
# Epoch 48/100
# 9/9 [==============================] - 1s 144ms/step - loss: 0.2168 - mae: 0.3566 - val_loss: 0.3498 - val_mae: 0.3659
# Epoch 49/100
# 9/9 [==============================] - 1s 140ms/step - loss: 0.2163 - mae: 0.3579 - val_loss: 0.3454 - val_mae: 0.3612
# Epoch 50/100
# 9/9 [==============================] - 1s 148ms/step - loss: 0.2045 - mae: 0.3384 - val_loss: 0.3463 - val_mae: 0.3640
# Epoch 51/100
# 9/9 [==============================] - 1s 148ms/step - loss: 0.1967 - mae: 0.3457 - val_loss: 0.3421 - val_mae: 0.3687
# Epoch 52/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.2013 - mae: 0.3390 - val_loss: 0.3444 - val_mae: 0.3635
# Epoch 53/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.1956 - mae: 0.3388 - val_loss: 0.3453 - val_mae: 0.3728
# Epoch 54/100
# 9/9 [==============================] - 1s 150ms/step - loss: 0.1871 - mae: 0.3282 - val_loss: 0.3376 - val_mae: 0.3603
# Epoch 55/100
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1745 - mae: 0.3120 - val_loss: 0.3451 - val_mae: 0.3749
# Epoch 56/100
# 9/9 [==============================] - 1s 135ms/step - loss: 0.1649 - mae: 0.3063 - val_loss: 0.3396 - val_mae: 0.3625
# Epoch 57/100
# 9/9 [==============================] - 1s 136ms/step - loss: 0.1682 - mae: 0.3065 - val_loss: 0.3365 - val_mae: 0.3668
# Epoch 58/100
# 9/9 [==============================] - 1s 136ms/step - loss: 0.1571 - mae: 0.3062 - val_loss: 0.3370 - val_mae: 0.3617
# Epoch 59/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.1514 - mae: 0.2943 - val_loss: 0.3565 - val_mae: 0.3847
# Epoch 60/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.1584 - mae: 0.2980 - val_loss: 0.3395 - val_mae: 0.3672
# Epoch 61/100
# 9/9 [==============================] - 1s 146ms/step - loss: 0.1305 - mae: 0.2738 - val_loss: 0.3493 - val_mae: 0.3813
# Epoch 62/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.1246 - mae: 0.2718 - val_loss: 0.3462 - val_mae: 0.3705
# Epoch 63/100
# 9/9 [==============================] - 1s 148ms/step - loss: 0.1235 - mae: 0.2685 - val_loss: 0.3508 - val_mae: 0.3812
# Epoch 64/100
# 9/9 [==============================] - 1s 150ms/step - loss: 0.1167 - mae: 0.2606 - val_loss: 0.3498 - val_mae: 0.3682
# Epoch 65/100
# 9/9 [==============================] - 1s 151ms/step - loss: 0.1176 - mae: 0.2637 - val_loss: 0.3725 - val_mae: 0.4039
# Epoch 66/100
# 9/9 [==============================] - 1s 148ms/step - loss: 0.1255 - mae: 0.2726 - val_loss: 0.3635 - val_mae: 0.3947
# Epoch 67/100
# 9/9 [==============================] - 1s 137ms/step - loss: 0.1226 - mae: 0.2674 - val_loss: 0.3846 - val_mae: 0.4082
# Epoch 68/100
# 9/9 [==============================] - 1s 140ms/step - loss: 0.1199 - mae: 0.2603 - val_loss: 0.3867 - val_mae: 0.4209
# Epoch 69/100
# 9/9 [==============================] - 1s 148ms/step - loss: 0.1115 - mae: 0.2550 - val_loss: 0.3641 - val_mae: 0.3928
# Epoch 70/100
# 9/9 [==============================] - 1s 137ms/step - loss: 0.0949 - mae: 0.2355 - val_loss: 0.3642 - val_mae: 0.3763
# Epoch 71/100
# 9/9 [==============================] - 1s 149ms/step - loss: 0.0816 - mae: 0.2194 - val_loss: 0.3554 - val_mae: 0.3863
# Epoch 72/100
# 9/9 [==============================] - 1s 147ms/step - loss: 0.0831 - mae: 0.2196 - val_loss: 0.3630 - val_mae: 0.3815
# Epoch 73/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.0771 - mae: 0.2088 - val_loss: 0.3786 - val_mae: 0.3989
# Epoch 74/100
# 9/9 [==============================] - 1s 149ms/step - loss: 0.0923 - mae: 0.2330 - val_loss: 0.3584 - val_mae: 0.3862
# Epoch 75/100
# 9/9 [==============================] - 1s 136ms/step - loss: 0.0762 - mae: 0.2128 - val_loss: 0.3893 - val_mae: 0.4079
# Epoch 76/100
# 9/9 [==============================] - 1s 137ms/step - loss: 0.0818 - mae: 0.2154 - val_loss: 0.3847 - val_mae: 0.4016
# Epoch 77/100
# 9/9 [==============================] - 1s 149ms/step - loss: 0.0737 - mae: 0.2049 - val_loss: 0.3740 - val_mae: 0.3929
# Epoch 78/100
# 9/9 [==============================] - 1s 152ms/step - loss: 0.0707 - mae: 0.1964 - val_loss: 0.3795 - val_mae: 0.3945
# Epoch 79/100
# 9/9 [==============================] - 1s 145ms/step - loss: 0.0656 - mae: 0.1902 - val_loss: 0.3771 - val_mae: 0.3990
# Epoch 80/100
# 9/9 [==============================] - 1s 137ms/step - loss: 0.0714 - mae: 0.1957 - val_loss: 0.3908 - val_mae: 0.3979
# Epoch 81/100
# 9/9 [==============================] - 1s 152ms/step - loss: 0.0628 - mae: 0.1932 - val_loss: 0.3823 - val_mae: 0.4111
# Epoch 82/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.0690 - mae: 0.2003 - val_loss: 0.4196 - val_mae: 0.4242
# Epoch 83/100
# 9/9 [==============================] - 1s 137ms/step - loss: 0.0648 - mae: 0.1943 - val_loss: 0.3783 - val_mae: 0.4054
# Epoch 84/100
# 9/9 [==============================] - 1s 137ms/step - loss: 0.0545 - mae: 0.1741 - val_loss: 0.3813 - val_mae: 0.3895
# Epoch 85/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.0566 - mae: 0.1693 - val_loss: 0.3799 - val_mae: 0.3991
# Epoch 86/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.0539 - mae: 0.1685 - val_loss: 0.3933 - val_mae: 0.4007
# Epoch 87/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.0475 - mae: 0.1586 - val_loss: 0.3842 - val_mae: 0.3963
# Epoch 88/100
# 9/9 [==============================] - 1s 147ms/step - loss: 0.0478 - mae: 0.1596 - val_loss: 0.3826 - val_mae: 0.3909
# Epoch 89/100
# 9/9 [==============================] - 1s 147ms/step - loss: 0.0466 - mae: 0.1486 - val_loss: 0.3893 - val_mae: 0.3973
# Epoch 90/100
# 9/9 [==============================] - 1s 140ms/step - loss: 0.0435 - mae: 0.1578 - val_loss: 0.4003 - val_mae: 0.4055
# Epoch 91/100
# 9/9 [==============================] - 1s 153ms/step - loss: 0.0477 - mae: 0.1547 - val_loss: 0.4047 - val_mae: 0.4122
# Epoch 92/100
# 9/9 [==============================] - 1s 151ms/step - loss: 0.0452 - mae: 0.1567 - val_loss: 0.3864 - val_mae: 0.3961
# Epoch 93/100
# 9/9 [==============================] - 1s 151ms/step - loss: 0.0469 - mae: 0.1576 - val_loss: 0.3998 - val_mae: 0.4042
# Epoch 94/100
# 9/9 [==============================] - 1s 149ms/step - loss: 0.0427 - mae: 0.1497 - val_loss: 0.3884 - val_mae: 0.3990
# Epoch 95/100
# 9/9 [==============================] - 1s 143ms/step - loss: 0.0406 - mae: 0.1431 - val_loss: 0.3935 - val_mae: 0.3931
# Epoch 96/100
# 9/9 [==============================] - 1s 136ms/step - loss: 0.0442 - mae: 0.1567 - val_loss: 0.3895 - val_mae: 0.3949
# Epoch 97/100
# 9/9 [==============================] - 1s 151ms/step - loss: 0.0441 - mae: 0.1501 - val_loss: 0.3844 - val_mae: 0.3972
# Epoch 98/100
# 9/9 [==============================] - 1s 145ms/step - loss: 0.0399 - mae: 0.1474 - val_loss: 0.3887 - val_mae: 0.3920
# Epoch 99/100
# 9/9 [==============================] - 1s 138ms/step - loss: 0.0399 - mae: 0.1442 - val_loss: 0.4003 - val_mae: 0.4148
# Epoch 100/100
# 9/9 [==============================] - 1s 139ms/step - loss: 0.0408 - mae: 0.1453 - val_loss: 0.3913 - val_mae: 0.3907

# %%
loss, mae = multi_model.evaluate(
    [host_test, X_test],
    y_test,
)
# Step4.2 Plot the learning curve
plt.plot(multi_model_history.history["loss"], label="train")
plt.plot(multi_model_history.history["val_loss"], label="val")
plt.show()
# Out:
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1964 - mae: 0.3370

# %%
predict_train = multi_model.predict([host_train, X_train])
predict_test = multi_model.predict([host_test, X_test])
print("RMSE on train data: ", mean_squared_error(y_train, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(y_test, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.32065627294174914
# RMSE on test data:  0.4431441572219193

# %%
# model for Photo image
image_inputs_x = tf.keras.Input((64, 64, 3))

# for first images
x_image = tf.keras.layers.Conv2D(
    filters=64, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(image_inputs_x)

x_image = (MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))(x_image)

x_image = tf.keras.layers.Conv2D(
    filters=128, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(x_image)

x_image = (MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))(x_image)

x_image = tf.keras.layers.Conv2D(
    filters=64, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(x_image)

x_image = tf.keras.layers.Flatten()(x_image)

x_image = tf.keras.layers.Dense(128, activation="relu")(x_image)

x_image = tf.keras.layers.Dropout(0.5)(x_image)


# for second images
image_inputs_z = tf.keras.Input((64, 64, 3))

z_image = tf.keras.layers.Conv2D(
    filters=64, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(image_inputs_z)

z_image = (MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))(z_image)

z_image = tf.keras.layers.Conv2D(
    filters=128, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(z_image)

z_image = (MaxPool2D(pool_size=(3, 3), strides=2, padding="VALID"))(z_image)

z_image = tf.keras.layers.Conv2D(
    filters=64, kernel_size=(3, 3), strides=2, activation="relu", padding="same"
)(z_image)

z_image = tf.keras.layers.Flatten()(z_image)

z_image = tf.keras.layers.Dense(128, activation="relu")(z_image)

z_image = tf.keras.layers.Dropout(0.5)(z_image)


# model for Meta data
meta_inputs = tf.keras.Input(shape=((13,)))
x_meta = tf.keras.layers.Dense(13, activation="relu")(meta_inputs)
x_meta = tf.keras.layers.Dense(24, activation="relu")(x_meta)
x_meta = tf.keras.layers.Dense(12, activation="relu")(x_meta)

# concat
x = tf.keras.layers.Concatenate(axis=1)([x_image, x_meta, z_image])
output = tf.keras.layers.Dense(1, activation="linear")(x)

multi_multi_model = tf.keras.Model(
    inputs=[image_inputs_x, meta_inputs, image_inputs_z], outputs=output
)

# %%
multi_multi_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  input_6 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   1792        ['input_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   1792        ['input_6[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 15, 15, 64)  0           ['conv2d_10[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 15, 15, 64)  0           ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 128)    73856       ['max_pooling2d_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    73856       ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 128)   0           ['conv2d_11[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 128)   0           ['conv2d_14[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 2, 2, 64)     73792       ['max_pooling2d_7[0][0]']
#
#  input_7 (InputLayer)           [(None, 13)]         0           []
#
#  conv2d_15 (Conv2D)             (None, 2, 2, 64)     73792       ['max_pooling2d_9[0][0]']
#
#  flatten_3 (Flatten)            (None, 256)          0           ['conv2d_12[0][0]']
#
#  dense_31 (Dense)               (None, 13)           182         ['input_7[0][0]']
#
#  flatten_4 (Flatten)            (None, 256)          0           ['conv2d_15[0][0]']
#
#  dense_29 (Dense)               (None, 128)          32896       ['flatten_3[0][0]']
#
#  dense_32 (Dense)               (None, 24)           336         ['dense_31[0][0]']
#
#  dense_30 (Dense)               (None, 128)          32896       ['flatten_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_29[0][0]']
#
#  dense_33 (Dense)               (None, 12)           300         ['dense_32[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['dense_30[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 268)          0           ['dropout_4[0][0]',
#                                                                   'dense_33[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  dense_34 (Dense)               (None, 1)            269         ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 365,759
# Trainable params: 365,759
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
multi_multi_model.compile(loss="mse", metrics=["mae"], optimizer="adam")

callback = EarlyStopping(monitor="loss", patience=10)

# train the model
multi_multi_model_history = multi_multi_model.fit(
    [host_train, X_train, flat_train],
    y_train,
    validation_split=split,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[callback],
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 4s 293ms/step - loss: 5.7205 - mae: 1.9612 - val_loss: 0.8278 - val_mae: 0.6667
# Epoch 2/100
# 9/9 [==============================] - 2s 259ms/step - loss: 1.5684 - mae: 1.0348 - val_loss: 0.9627 - val_mae: 0.7054
# Epoch 3/100
# 9/9 [==============================] - 2s 253ms/step - loss: 1.1393 - mae: 0.7789 - val_loss: 0.8269 - val_mae: 0.7078
# Epoch 4/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.8242 - mae: 0.7113 - val_loss: 0.7923 - val_mae: 0.7106
# Epoch 5/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.6984 - mae: 0.6615 - val_loss: 0.6787 - val_mae: 0.6421
# Epoch 6/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.6071 - mae: 0.6078 - val_loss: 0.5753 - val_mae: 0.5715
# Epoch 7/100
# 9/9 [==============================] - 2s 248ms/step - loss: 0.5758 - mae: 0.5902 - val_loss: 0.5428 - val_mae: 0.5423
# Epoch 8/100
# 9/9 [==============================] - 2s 244ms/step - loss: 0.5204 - mae: 0.5559 - val_loss: 0.4899 - val_mae: 0.5112
# Epoch 9/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.5090 - mae: 0.5547 - val_loss: 0.4692 - val_mae: 0.4922
# Epoch 10/100
# 9/9 [==============================] - 2s 246ms/step - loss: 0.5225 - mae: 0.5527 - val_loss: 0.4542 - val_mae: 0.4772
# Epoch 11/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.4992 - mae: 0.5460 - val_loss: 0.4418 - val_mae: 0.4637
# Epoch 12/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.4991 - mae: 0.5465 - val_loss: 0.4284 - val_mae: 0.4486
# Epoch 13/100
# 9/9 [==============================] - 2s 256ms/step - loss: 0.4823 - mae: 0.5385 - val_loss: 0.4324 - val_mae: 0.4578
# Epoch 14/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.5176 - mae: 0.5600 - val_loss: 0.4264 - val_mae: 0.4517
# Epoch 15/100
# 9/9 [==============================] - 2s 257ms/step - loss: 0.4781 - mae: 0.5300 - val_loss: 0.4513 - val_mae: 0.4739
# Epoch 16/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.4069 - mae: 0.4957 - val_loss: 0.4136 - val_mae: 0.4474
# Epoch 17/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.4302 - mae: 0.5030 - val_loss: 0.4095 - val_mae: 0.4438
# Epoch 18/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.3923 - mae: 0.4915 - val_loss: 0.4084 - val_mae: 0.4420
# Epoch 19/100
# 9/9 [==============================] - 2s 245ms/step - loss: 0.3881 - mae: 0.4826 - val_loss: 0.4169 - val_mae: 0.4510
# Epoch 20/100
# 9/9 [==============================] - 2s 246ms/step - loss: 0.4269 - mae: 0.5093 - val_loss: 0.4382 - val_mae: 0.4660
# Epoch 21/100
# 9/9 [==============================] - 2s 243ms/step - loss: 0.4105 - mae: 0.5017 - val_loss: 0.4117 - val_mae: 0.4478
# Epoch 22/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.4382 - mae: 0.5113 - val_loss: 0.4277 - val_mae: 0.4604
# Epoch 23/100
# 9/9 [==============================] - 2s 239ms/step - loss: 0.3612 - mae: 0.4560 - val_loss: 0.4276 - val_mae: 0.4568
# Epoch 24/100
# 9/9 [==============================] - 2s 249ms/step - loss: 0.3564 - mae: 0.4533 - val_loss: 0.3883 - val_mae: 0.4239
# Epoch 25/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.3595 - mae: 0.4568 - val_loss: 0.3811 - val_mae: 0.4151
# Epoch 26/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.3494 - mae: 0.4564 - val_loss: 0.3804 - val_mae: 0.4172
# Epoch 27/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.3315 - mae: 0.4378 - val_loss: 0.3824 - val_mae: 0.4180
# Epoch 28/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.3429 - mae: 0.4577 - val_loss: 0.3898 - val_mae: 0.4204
# Epoch 29/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.3561 - mae: 0.4590 - val_loss: 0.3895 - val_mae: 0.4206
# Epoch 30/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.3492 - mae: 0.4463 - val_loss: 0.3744 - val_mae: 0.4141
# Epoch 31/100
# 9/9 [==============================] - 2s 268ms/step - loss: 0.3030 - mae: 0.4188 - val_loss: 0.3728 - val_mae: 0.4138
# Epoch 32/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.3043 - mae: 0.4241 - val_loss: 0.3950 - val_mae: 0.4302
# Epoch 33/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.3005 - mae: 0.4243 - val_loss: 0.3908 - val_mae: 0.4271
# Epoch 34/100
# 9/9 [==============================] - 2s 264ms/step - loss: 0.2724 - mae: 0.4066 - val_loss: 0.3777 - val_mae: 0.4161
# Epoch 35/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.2631 - mae: 0.4038 - val_loss: 0.3720 - val_mae: 0.4061
# Epoch 36/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.2520 - mae: 0.3893 - val_loss: 0.3824 - val_mae: 0.4197
# Epoch 37/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.2471 - mae: 0.3833 - val_loss: 0.3779 - val_mae: 0.4154
# Epoch 38/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.2225 - mae: 0.3624 - val_loss: 0.3689 - val_mae: 0.4056
# Epoch 39/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.2204 - mae: 0.3583 - val_loss: 0.3788 - val_mae: 0.4185
# Epoch 40/100
# 9/9 [==============================] - 2s 250ms/step - loss: 0.2048 - mae: 0.3542 - val_loss: 0.3657 - val_mae: 0.4015
# Epoch 41/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.2176 - mae: 0.3615 - val_loss: 0.3997 - val_mae: 0.4339
# Epoch 42/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.2047 - mae: 0.3503 - val_loss: 0.3707 - val_mae: 0.4076
# Epoch 43/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.1878 - mae: 0.3415 - val_loss: 0.4357 - val_mae: 0.4617
# Epoch 44/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.1716 - mae: 0.3235 - val_loss: 0.3861 - val_mae: 0.4200
# Epoch 45/100
# 9/9 [==============================] - 2s 255ms/step - loss: 0.1540 - mae: 0.3092 - val_loss: 0.4100 - val_mae: 0.4428
# Epoch 46/100
# 9/9 [==============================] - 2s 264ms/step - loss: 0.1438 - mae: 0.2955 - val_loss: 0.3951 - val_mae: 0.4327
# Epoch 47/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.1344 - mae: 0.2886 - val_loss: 0.3895 - val_mae: 0.4344
# Epoch 48/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.1259 - mae: 0.2781 - val_loss: 0.4692 - val_mae: 0.4781
# Epoch 49/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.1325 - mae: 0.2768 - val_loss: 0.3834 - val_mae: 0.4155
# Epoch 50/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.1200 - mae: 0.2693 - val_loss: 0.3790 - val_mae: 0.4221
# Epoch 51/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.1239 - mae: 0.2750 - val_loss: 0.3916 - val_mae: 0.4266
# Epoch 52/100
# 9/9 [==============================] - 2s 249ms/step - loss: 0.1144 - mae: 0.2633 - val_loss: 0.3846 - val_mae: 0.4191
# Epoch 53/100
# 9/9 [==============================] - 2s 257ms/step - loss: 0.1125 - mae: 0.2640 - val_loss: 0.3831 - val_mae: 0.4116
# Epoch 54/100
# 9/9 [==============================] - 2s 243ms/step - loss: 0.0870 - mae: 0.2263 - val_loss: 0.4823 - val_mae: 0.4881
# Epoch 55/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0968 - mae: 0.2400 - val_loss: 0.3783 - val_mae: 0.4091
# Epoch 56/100
# 9/9 [==============================] - 2s 255ms/step - loss: 0.0760 - mae: 0.2058 - val_loss: 0.3929 - val_mae: 0.4198
# Epoch 57/100
# 9/9 [==============================] - 2s 249ms/step - loss: 0.0713 - mae: 0.2056 - val_loss: 0.3788 - val_mae: 0.4063
# Epoch 58/100
# 9/9 [==============================] - 2s 241ms/step - loss: 0.0734 - mae: 0.2041 - val_loss: 0.3697 - val_mae: 0.4050
# Epoch 59/100
# 9/9 [==============================] - 2s 239ms/step - loss: 0.0614 - mae: 0.1909 - val_loss: 0.3797 - val_mae: 0.4094
# Epoch 60/100
# 9/9 [==============================] - 2s 238ms/step - loss: 0.0561 - mae: 0.1826 - val_loss: 0.3904 - val_mae: 0.4168
# Epoch 61/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0506 - mae: 0.1696 - val_loss: 0.3954 - val_mae: 0.4213
# Epoch 62/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0503 - mae: 0.1713 - val_loss: 0.3976 - val_mae: 0.4234
# Epoch 63/100
# 9/9 [==============================] - 2s 242ms/step - loss: 0.0513 - mae: 0.1746 - val_loss: 0.3790 - val_mae: 0.4081
# Epoch 64/100
# 9/9 [==============================] - 2s 245ms/step - loss: 0.0482 - mae: 0.1701 - val_loss: 0.3924 - val_mae: 0.4161
# Epoch 65/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.0401 - mae: 0.1465 - val_loss: 0.4016 - val_mae: 0.4254
# Epoch 66/100
# 9/9 [==============================] - 2s 267ms/step - loss: 0.0370 - mae: 0.1408 - val_loss: 0.3945 - val_mae: 0.4195
# Epoch 67/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0378 - mae: 0.1441 - val_loss: 0.3886 - val_mae: 0.4140
# Epoch 68/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0344 - mae: 0.1406 - val_loss: 0.4030 - val_mae: 0.4303
# Epoch 69/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.0350 - mae: 0.1407 - val_loss: 0.4011 - val_mae: 0.4241
# Epoch 70/100
# 9/9 [==============================] - 2s 264ms/step - loss: 0.0453 - mae: 0.1645 - val_loss: 0.3835 - val_mae: 0.4163
# Epoch 71/100
# 9/9 [==============================] - 2s 258ms/step - loss: 0.0456 - mae: 0.1622 - val_loss: 0.4110 - val_mae: 0.4321
# Epoch 72/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.0318 - mae: 0.1333 - val_loss: 0.4004 - val_mae: 0.4221
# Epoch 73/100
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0300 - mae: 0.1318 - val_loss: 0.3927 - val_mae: 0.4145
# Epoch 74/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0276 - mae: 0.1224 - val_loss: 0.4110 - val_mae: 0.4293
# Epoch 75/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.0262 - mae: 0.1221 - val_loss: 0.3897 - val_mae: 0.4178
# Epoch 76/100
# 9/9 [==============================] - 2s 255ms/step - loss: 0.0313 - mae: 0.1332 - val_loss: 0.4009 - val_mae: 0.4223
# Epoch 77/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.0230 - mae: 0.1147 - val_loss: 0.4071 - val_mae: 0.4290
# Epoch 78/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.0209 - mae: 0.1078 - val_loss: 0.3999 - val_mae: 0.4187
# Epoch 79/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.0211 - mae: 0.1075 - val_loss: 0.4059 - val_mae: 0.4236
# Epoch 80/100
# 9/9 [==============================] - 2s 257ms/step - loss: 0.0181 - mae: 0.1032 - val_loss: 0.4122 - val_mae: 0.4284
# Epoch 81/100
# 9/9 [==============================] - 2s 252ms/step - loss: 0.0194 - mae: 0.1051 - val_loss: 0.4134 - val_mae: 0.4318
# Epoch 82/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0232 - mae: 0.1160 - val_loss: 0.3964 - val_mae: 0.4208
# Epoch 83/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0193 - mae: 0.1087 - val_loss: 0.3850 - val_mae: 0.4131
# Epoch 84/100
# 9/9 [==============================] - 2s 247ms/step - loss: 0.0202 - mae: 0.1062 - val_loss: 0.4008 - val_mae: 0.4213
# Epoch 85/100
# 9/9 [==============================] - 2s 259ms/step - loss: 0.0205 - mae: 0.1024 - val_loss: 0.3919 - val_mae: 0.4149
# Epoch 86/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.0171 - mae: 0.0919 - val_loss: 0.4244 - val_mae: 0.4375
# Epoch 87/100
# 9/9 [==============================] - 2s 255ms/step - loss: 0.0134 - mae: 0.0897 - val_loss: 0.3962 - val_mae: 0.4131
# Epoch 88/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0158 - mae: 0.0892 - val_loss: 0.4061 - val_mae: 0.4226
# Epoch 89/100
# 9/9 [==============================] - 2s 260ms/step - loss: 0.0140 - mae: 0.0876 - val_loss: 0.3920 - val_mae: 0.4179
# Epoch 90/100
# 9/9 [==============================] - 2s 253ms/step - loss: 0.0151 - mae: 0.0920 - val_loss: 0.3912 - val_mae: 0.4132
# Epoch 91/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0136 - mae: 0.0854 - val_loss: 0.4105 - val_mae: 0.4280
# Epoch 92/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.0152 - mae: 0.0916 - val_loss: 0.4073 - val_mae: 0.4232
# Epoch 93/100
# 9/9 [==============================] - 2s 257ms/step - loss: 0.0134 - mae: 0.0861 - val_loss: 0.3773 - val_mae: 0.4006
# Epoch 94/100
# 9/9 [==============================] - 2s 251ms/step - loss: 0.0149 - mae: 0.0946 - val_loss: 0.3981 - val_mae: 0.4188
# Epoch 95/100
# 9/9 [==============================] - 2s 245ms/step - loss: 0.0135 - mae: 0.0832 - val_loss: 0.4006 - val_mae: 0.4219
# Epoch 96/100
# 9/9 [==============================] - 2s 246ms/step - loss: 0.0137 - mae: 0.0836 - val_loss: 0.3978 - val_mae: 0.4167
# Epoch 97/100
# 9/9 [==============================] - 2s 266ms/step - loss: 0.0154 - mae: 0.0918 - val_loss: 0.4080 - val_mae: 0.4203
# Epoch 98/100
# 9/9 [==============================] - 2s 261ms/step - loss: 0.0129 - mae: 0.0848 - val_loss: 0.4046 - val_mae: 0.4171
# Epoch 99/100
# 9/9 [==============================] - 2s 254ms/step - loss: 0.0123 - mae: 0.0816 - val_loss: 0.4007 - val_mae: 0.4133
# Epoch 100/100
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0089 - mae: 0.0707 - val_loss: 0.3935 - val_mae: 0.4115

# %%
loss, mae = multi_multi_model.evaluate(
    [host_test, X_test, flat_test],
    y_test,
)
# Step4.2 Plot the learning curve
plt.plot(multi_multi_model_history.history["loss"], label="train")
plt.plot(multi_multi_model_history.history["val_loss"], label="val")
plt.show()
# Out:
# 10/10 [==============================] - 0s 34ms/step - loss: 0.4489 - mae: 0.4037

# %%
predict_train = multi_multi_model.predict([host_train, X_train, flat_train])
predict_test = multi_multi_model.predict([host_test, X_test, flat_test])
print("RMSE on train data: ", mean_squared_error(y_train, predict_train) ** (0.5))
print("RMSE on test data: ", mean_squared_error(y_test, predict_test) ** (0.5))
# Out:
# RMSE on train data:  0.28651234761898486
# RMSE on test data:  0.6700301889096423

# %% [markdown]
# As this is just an introductory notebook, I again want to emphasize that the performance of these models is arbitrary and should not effect your model or variable choice.
#
# In this notebook we have started with very simple methods, suited to analyse structured data. Even in the performed models any form of optimizing is missing and the variable selection was done at random. Therefore you have plenty of room to build better fitting models using more suitable variables.
#
# Subsequently we have used 3 types of neural networks:
# * Multi Layer Perceptrons to analyze structured data
# * Convolutional Neural networks to analyze images
# * Mixed Input Neural Networks to analyze structured data and images combined
